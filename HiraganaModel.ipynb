# %% [markdown]
# <a href="https://colab.research.google.com/github/cs-dan/Self-Projects/blob/main/HiraganaModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Before running code (first script), upload the datasets into colab, they can be found in the given link:
#https://colab.research.google.com/drive/14sFiBgKDV-fQUNV6ckPRyxZtm5Ohew4n?usp=sharing
#
#Upload HiraganaR.npz for the first script.
#Upload weightsHiragana.npy for the second script to see accuracy for best trained weights so far.

# %%
####################################################################
######################### Hiragana Program #########################
####################################################################
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

################################################################################
######################### Convolution Neural Net Class #########################
#regarding weightMatrix, layerMatrix, derivativeMatrix
#defined as ""matrix[layer][(row,)-matrix] for layerMatrix/derivativeMatrix, where row = # of nodes 
#defined as ""matrix[layer][(row,col)-matrix] for weightMatrix/derivativeMatrix, where row = size of flattened sample, col = # of nodes


class cnn(object):
  def __init__(self, learning_rate=0.0005):
    self.c = learning_rate
    self.weightMatrix = [np.empty(shape=(0,0)),np.empty(shape=(0,0))]  #list holding weights from each time weight was called.
    self.layerMatrix = [np.empty(shape=(0,0)),np.empty(shape=(0,0)),np.empty(shape=(0,0))] #list holding node values from each dense layer 
    self.derivativeMatrix = [np.empty(shape=(0,0)),np.empty(shape=(0,0))] #list holding derivatives for each layer
    self.char = ['あ','い','う','え','お','か','が','き','ぎ','く','ぐ','け','げ','こ','ご','さ','ざ','し','じ','す','ず','せ','ぜ','そ','ぞ','た','だ','ち','ぢ','つ','づ','て','で','と','ど','な','に','ぬ','ね','の','は','ば','ぱ','ひ','び','ぴ','ふ','ぶ','ぷ','へ','べ','ぺ','ほ','ぼ','ぽ','ま','み','む','め','も','や','ゆ','よ','ら','り','る','れ','ろ','わ','を','ん',]
    self.correct = 0
    self.accuracyF = np.empty(shape=(0,), dtype=float)
    self.lossF = np.empty(shape=(0,), dtype=float)

  def conv1(self, input, kernel_size=(3,3), strides=(1,1), padding = 2):
    """ First convolutional layer """
    input = input
    kernel1 = np.array([[[0,-3,0],[-3,15,-3],[0,-3,0]]]) #sharpening filter
    kernel2 = np.array([[[-5,-15,-5],[0,0,0],[5,15,5]]]) #vertical filter
    kernel3 = np.array([[[-5,0,5],[-15,0,15],[-5,0,5]]]) #horizontal filter    
    filter = np.concatenate((kernel1, kernel2, kernel3))
    output = np.zeros(shape=(filter.shape[0], input.shape[0]-2, input.shape[1]-2))
    window = np.zeros(shape=(3,3))
    B = -1
    for i in range(filter.shape[0]): #per kernel
      for j in range(input.shape[0] - 2 ):  #rows
        for k in range(input.shape[1] - 2 ): #columns 
          window = input[j:j+3, k:k+3]   #select window 
          activation = self.ReLu( np.sum(np.tensordot(window, filter[i])) + B) #
          output[i,j,k] = activation #Y = B + X*K and activation  
    return output
  
  def conv2(self, input, kernel_size=(3,3), strides=(1,1), padding=2):
    """Second convolutional layer"""
    input = input
    kernel1 = np.array([[[0,-1,0],[-1,5,-1],[0,-1,0]]]) #vertical filter
    kernel2 = np.array([[[-1,-2,-1],[0,0,0],[1,2,1]]]) #vertical filter
    kernel3 = np.array([[[-1,0,1],[-2,0,2],[-1,0,1]]]) #horizontal filter
    filter = np.concatenate((kernel1, kernel2, kernel3))
    output = np.zeros(shape=(input.shape[0], input.shape[1]-2, input.shape[2]-2))
    window = np.zeros(shape=(3,3))
    B = -1
    for i in range(input.shape[0]):
      for j in range(input.shape[1] - 2 ):  #rows
        for k in range(input.shape[2] - 2 ): #columns 
          window = input[i, j:j+3, k:k+3]   #select window 
          activation = self.ReLu( np.sum(np.tensordot(window, filter[i])) + B) 
          output[i,j,k] = activation #Y = B + X*K and activation
    return output

  def conv3(self, input, kernel_size=(3,3), strides=(1,1), padding=2):
    """Third convolutional layer"""
    input = input
    kernel1 = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]]) #sharpening filter
    output = np.zeros(shape=(input.shape[0], input.shape[1]-2, input.shape[2]-2))
    window = np.zeros(shape=(3,3))
    B = -1
    for i in range(input.shape[0]): #per kernel
      for j in range(input.shape[1] - 2 ):  #rows
        for k in range(input.shape[2] - 2 ): #columns 
          window = input[i, j:j+3, k:k+3]   #select window 
          activation = self.ReLu( np.sum(np.tensordot(window, kernel1)) + B) #
          output[i,j,k] = activation #Y = B + X*K and activation
    return output

  def pooling(self, input, pool_size=(2,2), strides=(2,2)):
    """Pooling layer to extract max"""
    self.arr = input  #input set of convoluted images 
    output = np.zeros(shape=(input.shape[0], int(input.shape[1]/strides[0]), int(input.shape[2]/strides[1]))) #shape of output
    for i in range(self.arr.shape[0]): #per feature map
      for j in range(0, self.arr.shape[1], strides[0]): #rows
        for k in range(0, self.arr.shape[2], strides[1]): #columns
          if int(j/2) >= output.shape[1] or int(k/2) >= output.shape[2]: break
          window = self.arr[i, j:j+strides[0], k:k+strides[1]]   #select window    #mistake: you set self.arr to np.arr instead, generating random vals
          output[i,int(j/2),int(k/2)] = np.max(window)   #get max from window
    return output   #output pool layers

  def flatten(self, input):
    """reshape layer"""
    output = np.reshape(input, input.size)    #reshape all array elements into a 1d array
    return output #output flattened layers

  def denseSetup(self, input, layers, nodes, skip=False):
    """setting up fully connection section"""
    random = np.random.RandomState(1)
    self.layerMatrix[0] = np.zeros(shape=(input.size+1,))
    self.layerMatrix[1] = np.zeros(shape=(nodes[0],))
    self.layerMatrix[2] = np.zeros(shape=(nodes[1],))
    for i in range(layers):
      if skip == False:
        self.weightMatrix[i] = random.normal(loc=0.0, scale=0.1, size=(self.layerMatrix[i].shape[0], nodes[i])) #weights per node
      self.derivativeMatrix[i] = np.zeros(shape=(nodes[i],)) #layer derivatives 
  
  def denseNetwork(self, input): 
    """fully connected section, forward pass"""
    self.layerMatrix[0] = input  #input layer
    self.layerMatrix[0] = np.append(self.layerMatrix[0], 1)
    self.layerMatrix[0] = self.layerMatrix[0] / 10
    l=0
    for l in range(len(self.layerMatrix)-1):
      next = l + 1
      for i in range(self.layerMatrix[next].shape[0]):  #next layer num nodes
        if next == len(self.layerMatrix)-1: 
          self.layerMatrix[next][i] = np.dot(self.layerMatrix[l], self.weightMatrix[l][:,i])
        else: 
          self.layerMatrix[next][i] = self.ReLu(np.dot(self.layerMatrix[l], self.weightMatrix[l][:,i]))
    self.layerMatrix[2] = self.softMax(self.layerMatrix[len(self.layerMatrix)-1]) #output layer
    self.layerMatrix[2][np.abs(self.layerMatrix[2]) < 1e-7] = 1e-7 #array[np.abs(array) < eps] = 0
    self.biggest = np.argmax(self.layerMatrix[2])
    return self.layerMatrix[2]

  def denseBack(self, loss):
    """fully connected section, backpropagation"""
    derivative1 = np.zeros(shape=(self.layerMatrix[2].shape[0]))  #derivative array at output
    derivative2 = np.zeros(shape=(self.layerMatrix[1].shape[0]))  #derivative array at hidden

    #output layer to hidden layer 
    for i in range(self.layerMatrix[1].shape[0]):  #for layer below current (hidden)
      for j in range(self.layerMatrix[2].shape[0]):  #for current layer (output)
        derivative1[j] = -self.target[j] + self.layerMatrix[2][j]   #crossentropy loss - softmax derivative
        dLayer = self.layerMatrix[1][i]*derivative1[j]*self.c #- self.m*derivative1[j]  #activation*derivative*learning rate
        self.weightMatrix[1][i,j] -= dLayer

    #hidden layer to flatten layer 
    for i in range(self.layerMatrix[0].shape[0]):
      for j in range(self.layerMatrix[1].shape[0]):
        derivative2[j] = np.greater(self.layerMatrix[1][j], 0).astype(int)*np.dot(derivative1, self.weightMatrix[1][j])  #relu - past derivative derivative
        dLayer = self.layerMatrix[0][i]*derivative2[j]*self.c #- self.m*derivative2[j]
        self.weightMatrix[0][i,j] -= dLayer

  def ReLu(self, input):
    return max(0.0, input)   # if greater than 0, return num, if less than 0, return 0

  def Loss(self, output): 
    """categorical cross-entropy loss"""
    return -np.sum(self.target*np.log(output))   #loss = -sum(class*ln(output))

  def softMax(self, input):
    return np.exp(input)/np.sum(np.exp(input), axis=0)

  def encode(self, classes, target):
    """one hot encode"""
    target.fill(0) 
    target[classes] = 1
    return target

  def predictPreloaded(self, data, targets):
    """predict function for loading saved weights"""
    self.loadWeights()
    self.target = np.zeros((71,),dtype=int)
    for i in range(data.shape[0]):
      input = data[i]
      input = self.conv1(input=input)
      input = self.pooling(input=input)
      input = self.conv2(input=input)
      input = self.pooling(input=input)
      input = self.flatten(input=input)
      if i == 0: 
        self.denseSetup(input, layers=2,nodes=[12*12*2,48], skip=True)
      output = self.denseNetwork(input=input)
      self.target = self.encode(targets[i], self.target)
      if np.argmax(output) == self.target[i]:
        self.correct += 1
      print("predicted: ", np.argmax(output))
      print("actual: ", targets[i])
    print(self.accuracy.shape, data.shape)
    print("Predicition Accuracy Rate: ", 100*(self.correct/data.shape[0]))   #(self.accuracy.shape[0]/data.shape[0]), "%")
    self.correct = 0

  def predict(self, data, targets):
    """predict function for training"""
    for i in range(data.shape[0]):
      input = data[i]
      input = self.conv1(input=input)
      input = self.pooling(input=input)
      input = self.conv2(input=input)
      input = self.pooling(input=input)
      input = self.flatten(input=input)
      output = self.denseNetwork(input=input)
      self.target = self.encode(targets[i], self.target)
      if np.argmax(output) == targets[i]:
        self.correct += 1
      print("predicted: ", np.argmax(output))
      print("actual: ", targets[i])
    print("Prediction Accuracy Rate: ", 100*(self.accuracy.shape[0]/data.shape[0]), "%")
    self.accuracyF = np.append(self.accuracyF, 100*(self.correct/data.shape[0]))  #(self.accuracy.shape[0]/data.shape[0]))
    self.correct = 0 

  
  def fit(self, features, classes, epochs): 
    rest, features, restid, classes = train_test_split(images, classes, test_size=0.1875,  stratify=classes)
    """main training function"""
    self.target = np.zeros((71,),dtype=int)
    self.lossE = np.zeros(shape=(0,))
    error = 100
    epochLoss = 0
    print("Starting training...")
    for e in range(epochs):
      for i in range(features.shape[0]):
        if i > 50 and np.sum(self.lossF[i-50:i])/50 <= 1e-2:
          print("Early breaking condition reached. Acceptable loss range hit.")
          print("Loss was: ", error)
          self.saveWeights()
          return self
        ##################################
        ########## forward pass ##########
        input = features[i]
        input = self.conv1(input=input)
        input = self.pooling(input=input)
        input = self.conv2(input=input)
        input = self.pooling(input=input)
        input = self.conv3(input=input)
        input = self.flatten(input=input)
        if e == 0 and i == 0: 
          self.denseSetup(input, layers=2,nodes=[384,71])
        self.target = self.encode(classes[i], self.target)
        output = self.denseNetwork(input=input)
        ##########################
        ########## loss ##########
        error = self.Loss(output)
        self.lossF = np.append(self.lossF, error) #[i] = error
        epochLoss += error
        ###############################
        ########## back pass ##########
        self.denseBack(error)
        # if i % 100 == 0 and i > 0:    #every 100 iterations, test validation data
        #   self.predict(valid_data[0][int(i/10)-10:i], valid_data[1][int(i/10)-10:i])  #features, classes) #valid_data[0], valid_data[1])
        #   print("Loss is: ", error, " at ", i, " iterations.")
        print("Loss is: ", error, " at ", i, " iteration(s) at ", self.char[classes[i]], ".")
      self.lossE = np.append(self.lossE, epochLoss/features.shape[0]) #self.lossF.size)
      epochLoss = 0
      print("Loss at epoch = ", self.lossE[e])
      print("Epoch ", e+1, " completed.")
    print("Finished!")
    self.saveWeights()
    return self
  def saveWeights(self):
    w = np.asarray(self.weightMatrix, dtype=object)
    with open('weightsHiragana.npy', 'wb') as f:
      np.save(f, w)
  
  def loadWeights(self):
    with open('weightsHiragana.npy', 'rb') as f:
      temp = np.load(f, allow_pickle=True)
    for i in range(len(self.weightMatrix)):
      self.weightMatrix[i] = temp[i]
    print(len(self.weightMatrix))
    assert len(self.weightMatrix) == 2

############################################################################
############################## Data Init ##############################

loaded = np.load('hiraganaR.npz')
images = loaded['a']
classes = loaded['b']
print(images.shape, classes.shape)

########################################################################
############################## Model Init ##############################

model = cnn().fit(images, classes, 20 )

##################################################################################
############################## Metric Visualization ##############################

plt.plot(model.lossF) 
plt.ylabel('Loss')
plt.xlabel('Training Iterations')
plt.title('Loss vs # of Iterations')
plt.show()

plt.plot(model.lossE)
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.title('Loss vs # of Epochs')
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss is:  0.047202332904373985  at  1397  iteration(s) at  わ .
# Loss is:  0.05543193205228854  at  1398  iteration(s) at  い .
# Loss is:  0.007014982297077998  at  1399  iteration(s) at  て .
# Loss is:  0.3464870381010768  at  1400  iteration(s) at  も .
# Loss is:  0.02970860597958113  at  1401  iteration(s) at  の .
# Loss is:  0.010031505009001204  at  1402  iteration(s) at  れ .
# Loss is:  0.05016932799289261  at  1403  iteration(s) at  じ .
# Loss is:  0.0616396725985787  at  1404  iteration(s) at  げ .
# Loss is:  0.0034676129926730394  at  1405  iteration(s) at  だ .
# Loss is:  0.009071938387534761  at  1406  iteration(s) at  は .
# Loss is:  0.059654667297376986  at  1407  iteration(s) at  も .
# Loss is:  0.01328729211722464  at  1408  iteration(s) at  こ .
# Loss is:  0.002502619557712562  at  1409  iteration(s) at  げ .
# Loss is:  0.06919040957116238  at  1410  iteration(s) at  て .
# Loss is:  0.00436572920908027  at  1411  iteration(s) at  わ .
# Loss is:  0.016202368612439944  at  1412  iteration(s) at  ご .
# Loss is:  0.005997469508410195  at  1413  iteration(s) at  づ .
# Loss is:  0.0836849709726927  at  1414  iteration(s) at  だ .
# Loss is:  0.035685315926161636  at  1415  iteration(s) at  な .
# Loss is:  0.001971409876650626  at  1416  iteration(s) at  な .
# Loss is:  0.001765235466905874  at  1417  iteration(s) at  が .
# Loss is:  0.049487264937253445  at  1418  iteration(s) at  せ .
# Loss is:  0.05742693739712701  at  1419  iteration(s) at  よ .
# Loss is:  0.05993982712174104  at  1420  iteration(s) at  で .
# Loss is:  0.00016282401914352905  at  1421  iteration(s) at  り .
# Loss is:  0.01303645349192109  at  1422  iteration(s) at  た .
# Loss is:  0.03365962149602987  at  1423  iteration(s) at  に .
# Loss is:  0.06550711896744381  at  1424  iteration(s) at  ま .
# Loss is:  0.005462884920250216  at  1425  iteration(s) at  じ .
# Loss is:  2.189921166649793  at  1426  iteration(s) at  る .
# Loss is:  0.028078477449106676  at  1427  iteration(s) at  う .
# Loss is:  0.0014039738593686446  at  1428  iteration(s) at  き .
# Loss is:  0.22930410835270462  at  1429  iteration(s) at  は .
# Loss is:  0.17039171125694066  at  1430  iteration(s) at  の .
# Loss is:  0.5748843315504546  at  1431  iteration(s) at  で .
# Loss is:  0.0177456803842351  at  1432  iteration(s) at  そ .
# Loss is:  0.017686237488993024  at  1433  iteration(s) at  お .
# Loss is:  0.2326751587227125  at  1434  iteration(s) at  こ .
# Loss is:  0.0073022556760773795  at  1435  iteration(s) at  ぼ .
# Loss is:  0.004005334371719709  at  1436  iteration(s) at  ほ .
# Loss is:  0.07653289286774936  at  1437  iteration(s) at  ご .
# Loss is:  0.2650158455157706  at  1438  iteration(s) at  き .
# Loss is:  0.11051639136687308  at  1439  iteration(s) at  き .
# Loss is:  0.026863959481214682  at  1440  iteration(s) at  そ .
# Loss is:  0.056143657044183344  at  1441  iteration(s) at  さ .
# Loss is:  0.225434581742448  at  1442  iteration(s) at  か .
# Loss is:  0.19557890082232296  at  1443  iteration(s) at  ほ .
# Loss is:  7.483771161942758e-05  at  1444  iteration(s) at  く .
# Loss is:  0.024097505328497554  at  1445  iteration(s) at  ぱ .
# Loss is:  0.2766952253021295  at  1446  iteration(s) at  づ .
# Loss is:  0.1199757479276274  at  1447  iteration(s) at  と .
# Loss is:  0.0010775159246130973  at  1448  iteration(s) at  あ .
# Loss is:  0.004816904456165496  at  1449  iteration(s) at  や .
# Loss is:  0.04588138059223277  at  1450  iteration(s) at  ぺ .
# Loss is:  0.4035058257520667  at  1451  iteration(s) at  ど .
# Loss is:  0.002640181841710463  at  1452  iteration(s) at  く .
# Loss is:  0.01687788061636181  at  1453  iteration(s) at  た .
# Loss is:  0.046117728995673346  at  1454  iteration(s) at  ぬ .
# Loss is:  0.03054808326946257  at  1455  iteration(s) at  ざ .
# Loss is:  0.042735226265395165  at  1456  iteration(s) at  ぽ .
# Loss is:  0.010684442264715646  at  1457  iteration(s) at  は .
# Loss is:  0.04930780352749129  at  1458  iteration(s) at  ご .
# Loss is:  0.06185849660045091  at  1459  iteration(s) at  ひ .
# Loss is:  0.03338977366504563  at  1460  iteration(s) at  め .
# Loss is:  0.0789338486537451  at  1461  iteration(s) at  ん .
# Loss is:  0.014811053399999198  at  1462  iteration(s) at  ぷ .
# Loss is:  0.004351290394369807  at  1463  iteration(s) at  ぬ .
# Loss is:  0.24356702356273294  at  1464  iteration(s) at  ね .
# Loss is:  0.0002770864534720537  at  1465  iteration(s) at  そ .
# Loss is:  0.004059693312575736  at  1466  iteration(s) at  ど .
# Loss is:  0.0033919221302402525  at  1467  iteration(s) at  わ .
# Loss is:  0.006555017567063944  at  1468  iteration(s) at  ず .
# Loss is:  0.01678169679669606  at  1469  iteration(s) at  ぐ .
# Loss is:  0.03106983445294641  at  1470  iteration(s) at  ぞ .
# Loss is:  0.0009452140796376799  at  1471  iteration(s) at  ね .
# Loss is:  0.0037996822347083907  at  1472  iteration(s) at  ん .
# Loss is:  0.02758085929039992  at  1473  iteration(s) at  ね .
# Loss is:  0.05651470733807836  at  1474  iteration(s) at  ろ .
# Loss is:  0.009784008461038827  at  1475  iteration(s) at  と .
# Loss is:  0.021931504155227627  at  1476  iteration(s) at  こ .
# Loss is:  0.0951292516312586  at  1477  iteration(s) at  て .
# Loss is:  0.015586571445839538  at  1478  iteration(s) at  お .
# Loss is:  0.03699287190845756  at  1479  iteration(s) at  ぴ .
# Loss is:  0.10093510111465603  at  1480  iteration(s) at  ど .
# Loss is:  0.014958401826666226  at  1481  iteration(s) at  ご .
# Loss is:  0.08033636687666398  at  1482  iteration(s) at  ひ .
# Loss is:  0.023068038779865335  at  1483  iteration(s) at  べ .
# Loss is:  0.013973523828372055  at  1484  iteration(s) at  ぢ .
# Loss is:  0.0009226931165997912  at  1485  iteration(s) at  め .
# Loss is:  0.006670529282550204  at  1486  iteration(s) at  し .
# Loss is:  0.02286021973370085  at  1487  iteration(s) at  ば .
# Loss is:  0.08155957211705431  at  1488  iteration(s) at  と .
# Loss is:  0.13418331559695784  at  1489  iteration(s) at  て .
# Loss is:  0.02359198786280108  at  1490  iteration(s) at  せ .
# Loss is:  0.024755079072319223  at  1491  iteration(s) at  ぶ .
# Loss is:  0.17466038733569392  at  1492  iteration(s) at  せ .
# Loss is:  0.014627821040563406  at  1493  iteration(s) at  ふ .
# Loss is:  0.0229213724180504  at  1494  iteration(s) at  み .
# Loss is:  0.031450032100688655  at  1495  iteration(s) at  ぢ .
# Loss is:  0.0016206059964098624  at  1496  iteration(s) at  ん .
# Loss is:  0.04956340497045399  at  1497  iteration(s) at  ら .
# Loss is:  0.46178859816552303  at  1498  iteration(s) at  べ .
# Loss is:  0.002890433988383028  at  1499  iteration(s) at  が .
# Loss is:  0.13785004702643444  at  1500  iteration(s) at  べ .
# Loss is:  0.03666153111627853  at  1501  iteration(s) at  ま .
# Loss is:  0.04173491332940899  at  1502  iteration(s) at  が .
# Loss is:  0.03024578746323751  at  1503  iteration(s) at  ざ .
# Loss is:  0.030918929972822307  at  1504  iteration(s) at  ざ .
# Loss is:  0.0010680062551946868  at  1505  iteration(s) at  ぎ .
# Loss is:  0.002703732177554202  at  1506  iteration(s) at  ね .
# Loss is:  0.14868869242251462  at  1507  iteration(s) at  ば .
# Loss is:  0.08370703358513841  at  1508  iteration(s) at  で .
# Loss is:  0.09688210470958626  at  1509  iteration(s) at  け .
# Loss is:  0.017311719777252904  at  1510  iteration(s) at  し .
# Loss is:  0.09025972925161287  at  1511  iteration(s) at  ぬ .
# Loss is:  1.9243021058667002e-05  at  1512  iteration(s) at  わ .
# Loss is:  0.0020701453177041106  at  1513  iteration(s) at  ん .
# Loss is:  0.1351860602012074  at  1514  iteration(s) at  ぺ .
# Loss is:  0.10428663045835698  at  1515  iteration(s) at  め .
# Loss is:  0.08488117372055562  at  1516  iteration(s) at  び .
# Loss is:  0.11836336852898159  at  1517  iteration(s) at  み .
# Loss is:  0.0084976302412609  at  1518  iteration(s) at  さ .
# Loss is:  0.01141523575584921  at  1519  iteration(s) at  ま .
# Loss is:  0.018162732211317752  at  1520  iteration(s) at  ぶ .
# Loss is:  0.0002683271042997881  at  1521  iteration(s) at  う .
# Loss is:  0.02706184074483838  at  1522  iteration(s) at  あ .
# Loss is:  0.062191834674769964  at  1523  iteration(s) at  て .
# Loss is:  0.011526579626860732  at  1524  iteration(s) at  ぼ .
# Loss is:  0.003484514748996877  at  1525  iteration(s) at  ま .
# Loss is:  0.09091646710911866  at  1526  iteration(s) at  り .
# Loss is:  0.09305416999966651  at  1527  iteration(s) at  づ .
# Loss is:  0.04238628789891276  at  1528  iteration(s) at  ら .
# Loss is:  0.1158752037804177  at  1529  iteration(s) at  ば .
# Loss is:  0.024017249691977518  at  1530  iteration(s) at  ぽ .
# Loss is:  0.008273209070671897  at  1531  iteration(s) at  わ .
# Loss is:  0.07890206768325267  at  1532  iteration(s) at  ひ .
# Loss is:  0.010414347160849876  at  1533  iteration(s) at  へ .
# Loss is:  0.07448514139047788  at  1534  iteration(s) at  か .
# Loss is:  0.05648701216453559  at  1535  iteration(s) at  ほ .
# Loss is:  0.3604028653807727  at  1536  iteration(s) at  ご .
# Loss is:  0.0689273198278014  at  1537  iteration(s) at  か .
# Loss is:  0.03376112999277568  at  1538  iteration(s) at  よ .
# Loss is:  0.00030243089392762633  at  1539  iteration(s) at  れ .
# Loss is:  3.484619050887471e-06  at  1540  iteration(s) at  ぜ .
# Loss is:  0.013352234699597999  at  1541  iteration(s) at  な .
# Loss is:  0.1723989307894552  at  1542  iteration(s) at  ぼ .
# Loss is:  0.010606825368572718  at  1543  iteration(s) at  ぶ .
# Loss is:  0.0004738216067822113  at  1544  iteration(s) at  ぺ .
# Loss is:  0.024559064505454718  at  1545  iteration(s) at  び .
# Loss is:  0.0024356008608612183  at  1546  iteration(s) at  あ .
# Loss is:  0.014496922319779367  at  1547  iteration(s) at  そ .
# Loss is:  0.030788192654623958  at  1548  iteration(s) at  ぬ .
# Loss is:  0.037150394292663924  at  1549  iteration(s) at  が .
# Loss is:  0.02153289617838036  at  1550  iteration(s) at  ど .
# Loss is:  0.0017454468705314803  at  1551  iteration(s) at  も .
# Loss is:  0.047339816897332715  at  1552  iteration(s) at  る .
# Loss is:  0.1919400160835619  at  1553  iteration(s) at  な .
# Loss is:  0.04067494701641208  at  1554  iteration(s) at  こ .
# Loss is:  0.06987989670453608  at  1555  iteration(s) at  び .
# Loss is:  0.008600233798639986  at  1556  iteration(s) at  と .
# Loss is:  0.045688736793401546  at  1557  iteration(s) at  の .
# Loss is:  0.0007805767233464364  at  1558  iteration(s) at  も .
# Loss is:  0.01666403743458083  at  1559  iteration(s) at  く .
# Loss is:  0.0024337833257326385  at  1560  iteration(s) at  ぱ .
# Loss is:  0.00012338005771087438  at  1561  iteration(s) at  ふ .
# Loss is:  0.012406508894048216  at  1562  iteration(s) at  を .
# Loss is:  0.11870583906066141  at  1563  iteration(s) at  ば .
# Loss is:  0.11152783597051126  at  1564  iteration(s) at  し .
# Loss is:  0.0022753643105640126  at  1565  iteration(s) at  せ .
# Loss is:  0.007104647845966592  at  1566  iteration(s) at  る .
# Loss is:  0.0139017975231439  at  1567  iteration(s) at  ほ .
# Loss is:  0.03741512554862133  at  1568  iteration(s) at  ね .
# Loss is:  0.09864794760577351  at  1569  iteration(s) at  わ .
# Loss is:  0.00591943167193978  at  1570  iteration(s) at  げ .
# Loss is:  0.027976955937533996  at  1571  iteration(s) at  む .
# Loss is:  0.24534121541484058  at  1572  iteration(s) at  よ .
# Loss is:  0.00648205387513431  at  1573  iteration(s) at  し .
# Loss is:  0.0063401750671270105  at  1574  iteration(s) at  ら .
# Loss is:  1.5088592767298042e-05  at  1575  iteration(s) at  い .
# Loss is:  0.0016820050195799205  at  1576  iteration(s) at  ぽ .
# Loss is:  0.007358313018537821  at  1577  iteration(s) at  け .
# Loss is:  0.1080865651403395  at  1578  iteration(s) at  と .
# Loss is:  0.11618890802829906  at  1579  iteration(s) at  ら .
# Loss is:  0.025045688264498697  at  1580  iteration(s) at  の .
# Loss is:  0.001689598631044229  at  1581  iteration(s) at  ん .
# Loss is:  0.001321666896439958  at  1582  iteration(s) at  ご .
# Loss is:  0.0005005747994603192  at  1583  iteration(s) at  や .
# Loss is:  9.778164223489403e-05  at  1584  iteration(s) at  ゆ .
# Loss is:  0.00304589749837218  at  1585  iteration(s) at  ろ .
# Loss is:  0.14014998407078263  at  1586  iteration(s) at  き .
# Loss is:  0.01009551704663652  at  1587  iteration(s) at  つ .
# Loss is:  0.005585406254623413  at  1588  iteration(s) at  ぷ .
# Loss is:  0.05884442800381233  at  1589  iteration(s) at  か .
# Loss is:  0.0028111800353310735  at  1590  iteration(s) at  れ .
# Loss is:  0.017641303609514276  at  1591  iteration(s) at  ぬ .
# Loss is:  0.0066760143927063675  at  1592  iteration(s) at  ち .
# Loss is:  0.01099239624224317  at  1593  iteration(s) at  ぷ .
# Loss is:  0.024959017213904904  at  1594  iteration(s) at  ぽ .
# Loss is:  0.0008857380268510909  at  1595  iteration(s) at  せ .
# Loss is:  0.5932877385929055  at  1596  iteration(s) at  ぞ .
# Loss is:  0.2055103372909221  at  1597  iteration(s) at  み .
# Loss is:  0.1018518905437546  at  1598  iteration(s) at  を .
# Loss is:  0.06414318010269217  at  1599  iteration(s) at  ぶ .
# Loss is:  0.02932210908018402  at  1600  iteration(s) at  り .
# Loss is:  0.08389962289063674  at  1601  iteration(s) at  わ .
# Loss is:  0.029256629729069925  at  1602  iteration(s) at  ぱ .
# Loss is:  0.04186456710423623  at  1603  iteration(s) at  ろ .
# Loss is:  0.06951936808291764  at  1604  iteration(s) at  の .
# Loss is:  0.04634498032168356  at  1605  iteration(s) at  る .
# Loss is:  0.12095046228669969  at  1606  iteration(s) at  せ .
# Loss is:  0.08748498826501382  at  1607  iteration(s) at  が .
# Loss is:  0.060861779112178625  at  1608  iteration(s) at  で .
# Loss is:  0.007203623254138098  at  1609  iteration(s) at  べ .
# Loss is:  0.05187359441205825  at  1610  iteration(s) at  ぶ .
# Loss is:  0.032551687827658764  at  1611  iteration(s) at  ち .
# Loss is:  0.011116695732409592  at  1612  iteration(s) at  き .
# Loss is:  0.029511156329621504  at  1613  iteration(s) at  い .
# Loss is:  0.0013353830123963592  at  1614  iteration(s) at  ぜ .
# Loss is:  0.003799343387040822  at  1615  iteration(s) at  す .
# Loss is:  0.19343203702428147  at  1616  iteration(s) at  し .
# Loss is:  0.004672512596724372  at  1617  iteration(s) at  ろ .
# Loss is:  0.03456741229162027  at  1618  iteration(s) at  げ .
# Loss is:  0.04230614746643397  at  1619  iteration(s) at  ぷ .
# Loss is:  0.15329365176664117  at  1620  iteration(s) at  を .
# Loss is:  0.04531165861566931  at  1621  iteration(s) at  じ .
# Loss is:  0.00402534052598083  at  1622  iteration(s) at  つ .
# Loss is:  0.011539350449434979  at  1623  iteration(s) at  ゆ .
# Loss is:  0.023407350723157947  at  1624  iteration(s) at  と .
# Loss is:  0.00017333643130664405  at  1625  iteration(s) at  え .
# Loss is:  0.08864714439407288  at  1626  iteration(s) at  ず .
# Loss is:  0.05373975880194385  at  1627  iteration(s) at  ぴ .
# Loss is:  0.004763369545946606  at  1628  iteration(s) at  が .
# Loss is:  0.0006096433684998144  at  1629  iteration(s) at  め .
# Loss is:  0.023541958507183817  at  1630  iteration(s) at  ぎ .
# Loss is:  0.07429246113613124  at  1631  iteration(s) at  ど .
# Loss is:  0.011158108224163453  at  1632  iteration(s) at  ち .
# Loss is:  0.0003040915876163261  at  1633  iteration(s) at  れ .
# Loss is:  0.4890825832198743  at  1634  iteration(s) at  げ .
# Loss is:  0.06730138414417966  at  1635  iteration(s) at  ぽ .
# Loss is:  0.005423354304403002  at  1636  iteration(s) at  の .
# Loss is:  0.018280173045090258  at  1637  iteration(s) at  で .
# Loss is:  0.13259327328025755  at  1638  iteration(s) at  べ .
# Loss is:  0.005484363189864497  at  1639  iteration(s) at  に .
# Loss is:  0.05920325299404072  at  1640  iteration(s) at  ぎ .
# Loss is:  0.003656173346465908  at  1641  iteration(s) at  ぜ .
# Loss is:  0.0047257432181949015  at  1642  iteration(s) at  び .
# Loss is:  0.0016093006178270815  at  1643  iteration(s) at  へ .
# Loss is:  0.0322620782007607  at  1644  iteration(s) at  め .
# Loss is:  0.006515516156627355  at  1645  iteration(s) at  た .
# Loss is:  0.024976128364915143  at  1646  iteration(s) at  ぷ .
# Loss is:  0.00014242949521306634  at  1647  iteration(s) at  ぜ .
# Loss is:  0.017275932831222543  at  1648  iteration(s) at  む .
# Loss is:  0.00993616850599198  at  1649  iteration(s) at  ぺ .
# Loss is:  0.6529091528455943  at  1650  iteration(s) at  に .
# Loss is:  0.0003294131351982876  at  1651  iteration(s) at  た .
# Loss is:  0.35518718194092136  at  1652  iteration(s) at  む .
# Loss is:  0.04366262890281596  at  1653  iteration(s) at  ご .
# Loss is:  0.06493958289720192  at  1654  iteration(s) at  い .
# Loss is:  0.03964466444229693  at  1655  iteration(s) at  る .
# Loss is:  0.0031185015080034428  at  1656  iteration(s) at  べ .
# Loss is:  0.021990666266513175  at  1657  iteration(s) at  ず .
# Loss is:  0.010883074300947225  at  1658  iteration(s) at  の .
# Loss is:  0.020086378259199664  at  1659  iteration(s) at  む .
# Loss is:  0.013147834405222719  at  1660  iteration(s) at  さ .
# Loss is:  0.08249622746666216  at  1661  iteration(s) at  た .
# Loss is:  0.011390177643682107  at  1662  iteration(s) at  ね .
# Loss is:  0.0009243262346164631  at  1663  iteration(s) at  こ .
# Loss is:  0.13982928711585266  at  1664  iteration(s) at  い .
# Loss is:  0.08571282952606214  at  1665  iteration(s) at  ぐ .
# Loss is:  0.054821122405427816  at  1666  iteration(s) at  と .
# Loss is:  0.08911645177684956  at  1667  iteration(s) at  ぴ .
# Loss is:  0.008489622096127554  at  1668  iteration(s) at  せ .
# Loss is:  0.06171632346583929  at  1669  iteration(s) at  に .
# Loss is:  0.7074773536520841  at  1670  iteration(s) at  た .
# Loss is:  0.026075525532660328  at  1671  iteration(s) at  は .
# Loss is:  0.0008206936030311121  at  1672  iteration(s) at  ゆ .
# Loss is:  0.018002610792944417  at  1673  iteration(s) at  ひ .
# Loss is:  0.03455241278223685  at  1674  iteration(s) at  ぜ .
# Loss is:  0.036841972860938016  at  1675  iteration(s) at  ぐ .
# Loss is:  0.023063182234504306  at  1676  iteration(s) at  つ .
# Loss is:  0.009354361651650813  at  1677  iteration(s) at  ぞ .
# Loss is:  0.0036495942058205975  at  1678  iteration(s) at  ち .
# Loss is:  0.19019234089850334  at  1679  iteration(s) at  が .
# Loss is:  0.031643980283820705  at  1680  iteration(s) at  を .
# Loss is:  0.0017084612903908074  at  1681  iteration(s) at  め .
# Loss is:  0.14573911486735044  at  1682  iteration(s) at  び .
# Loss is:  0.07667834026756987  at  1683  iteration(s) at  ぴ .
# Loss is:  0.24461261494994765  at  1684  iteration(s) at  て .
# Loss is:  0.01018154746844231  at  1685  iteration(s) at  ぺ .
# Loss is:  0.056902055587789255  at  1686  iteration(s) at  げ .
# Loss is:  0.06607394739245198  at  1687  iteration(s) at  こ .
# Loss is:  0.02879063027135746  at  1688  iteration(s) at  ろ .
# Loss is:  0.00500427987398078  at  1689  iteration(s) at  み .
# Loss is:  0.013906329297699681  at  1690  iteration(s) at  ろ .
# Loss is:  0.034495021644316164  at  1691  iteration(s) at  ぜ .
# Loss is:  0.006159432635532626  at  1692  iteration(s) at  じ .
# Loss is:  0.00075881553003564  at  1693  iteration(s) at  う .
# Loss is:  0.017179606256522453  at  1694  iteration(s) at  つ .
# Loss is:  0.07656515152837012  at  1695  iteration(s) at  べ .
# Loss is:  0.06684471675115816  at  1696  iteration(s) at  そ .
# Loss is:  0.002689911149601878  at  1697  iteration(s) at  ひ .
# Loss is:  0.11853174651759862  at  1698  iteration(s) at  ぼ .
# Loss is:  0.11785470959530056  at  1699  iteration(s) at  た .
# Loss is:  0.005142735632055628  at  1700  iteration(s) at  よ .
# Loss is:  0.019719144265664852  at  1701  iteration(s) at  ば .
# Loss is:  0.020573419951401675  at  1702  iteration(s) at  は .
# Loss is:  0.005025156911665843  at  1703  iteration(s) at  だ .
# Loss is:  0.02811684092938081  at  1704  iteration(s) at  ぽ .
# Loss is:  0.05036820672601908  at  1705  iteration(s) at  ぎ .
# Loss is:  0.011552964508850974  at  1706  iteration(s) at  を .
# Loss is:  0.1030153281253502  at  1707  iteration(s) at  な .
# Loss is:  0.039557599807991284  at  1708  iteration(s) at  ぽ .
# Loss is:  0.04535701340682927  at  1709  iteration(s) at  う .
# Loss is:  0.0675959300946762  at  1710  iteration(s) at  つ .
# Loss is:  0.019775363625739426  at  1711  iteration(s) at  ぽ .
# Loss is:  0.0026397090881300966  at  1712  iteration(s) at  れ .
# Loss is:  0.03982684698919684  at  1713  iteration(s) at  よ .
# Loss is:  0.056997910927145574  at  1714  iteration(s) at  も .
# Loss is:  0.055209177858481284  at  1715  iteration(s) at  は .
# Loss is:  0.0004687835573520798  at  1716  iteration(s) at  て .
# Loss is:  0.0010989504853197239  at  1717  iteration(s) at  む .
# Loss is:  0.045363043733276966  at  1718  iteration(s) at  い .
# Loss is:  0.10321230571464111  at  1719  iteration(s) at  ぱ .
# Loss is:  0.0011110247293382976  at  1720  iteration(s) at  ば .
# Loss is:  0.013520318258691993  at  1721  iteration(s) at  ぶ .
# Loss is:  0.014341791989937064  at  1722  iteration(s) at  ん .
# Loss is:  0.019697414981404163  at  1723  iteration(s) at  か .
# Loss is:  0.10048990955889736  at  1724  iteration(s) at  る .
# Loss is:  0.06789633577015923  at  1725  iteration(s) at  ず .
# Loss is:  0.0654310797504852  at  1726  iteration(s) at  だ .
# Loss is:  0.0807877586409261  at  1727  iteration(s) at  か .
# Loss is:  0.02761980699890589  at  1728  iteration(s) at  よ .
# Loss is:  0.024012939641541775  at  1729  iteration(s) at  か .
# Loss is:  0.042996016009783214  at  1730  iteration(s) at  お .
# Loss is:  0.14660883664951524  at  1731  iteration(s) at  が .
# Loss is:  0.4589946255548835  at  1732  iteration(s) at  ら .
# Loss is:  0.015810174227081728  at  1733  iteration(s) at  だ .
# Loss is:  0.02957577782310191  at  1734  iteration(s) at  ぞ .
# Loss is:  0.0833788273388296  at  1735  iteration(s) at  べ .
# Loss is:  0.0947140526470052  at  1736  iteration(s) at  な .
# Loss is:  0.0060844870940303004  at  1737  iteration(s) at  り .
# Loss is:  0.014146929568676806  at  1738  iteration(s) at  り .
# Loss is:  0.04440058701962766  at  1739  iteration(s) at  ご .
# Loss is:  0.01588142823677977  at  1740  iteration(s) at  へ .
# Loss is:  0.30626076302692373  at  1741  iteration(s) at  ぴ .
# Loss is:  0.006023083971299055  at  1742  iteration(s) at  い .
# Loss is:  0.05129726685567199  at  1743  iteration(s) at  し .
# Loss is:  3.0481432252370884e-06  at  1744  iteration(s) at  わ .
# Loss is:  0.00286630341789448  at  1745  iteration(s) at  い .
# Loss is:  0.05297249596179094  at  1746  iteration(s) at  め .
# Loss is:  0.012053667129411609  at  1747  iteration(s) at  の .
# Loss is:  0.056581253446455704  at  1748  iteration(s) at  う .
# Loss is:  0.026090363793063516  at  1749  iteration(s) at  ぬ .
# Loss is:  0.21590344831720332  at  1750  iteration(s) at  す .
# Loss is:  0.001441405752967911  at  1751  iteration(s) at  ぜ .
# Loss is:  0.12422411414690548  at  1752  iteration(s) at  え .
# Loss is:  0.018257996435750375  at  1753  iteration(s) at  ら .
# Loss is:  0.004059191119690279  at  1754  iteration(s) at  え .
# Loss is:  0.0016124000911532255  at  1755  iteration(s) at  え .
# Loss is:  0.17929562927757436  at  1756  iteration(s) at  べ .
# Loss is:  0.05358400181791312  at  1757  iteration(s) at  ぷ .
# Loss is:  0.06917415819427732  at  1758  iteration(s) at  ひ .
# Loss is:  0.0011026406678926134  at  1759  iteration(s) at  ふ .
# Loss is:  0.12715775237999338  at  1760  iteration(s) at  で .
# Loss is:  0.0003212060718621081  at  1761  iteration(s) at  さ .
# Loss is:  0.04623685440704388  at  1762  iteration(s) at  が .
# Loss is:  0.00012100886498591856  at  1763  iteration(s) at  ま .
# Loss is:  0.005951067063752518  at  1764  iteration(s) at  と .
# Loss is:  0.07989944268521464  at  1765  iteration(s) at  さ .
# Loss is:  0.010417716950505251  at  1766  iteration(s) at  も .
# Loss is:  2.284589761287105e-05  at  1767  iteration(s) at  お .
# Loss is:  0.0009057531458903698  at  1768  iteration(s) at  こ .
# Loss is:  0.1469366051942611  at  1769  iteration(s) at  ね .
# Loss is:  0.07614706150006596  at  1770  iteration(s) at  で .
# Loss is:  0.031715621733514915  at  1771  iteration(s) at  ぼ .
# Loss is:  0.08923396559186754  at  1772  iteration(s) at  ぐ .
# Loss is:  0.1418127834058012  at  1773  iteration(s) at  ざ .
# Loss is:  0.01439567332851927  at  1774  iteration(s) at  ず .
# Loss is:  0.044897307359296305  at  1775  iteration(s) at  ぷ .
# Loss is:  0.053395101239016585  at  1776  iteration(s) at  ぼ .
# Loss is:  0.06740883481685357  at  1777  iteration(s) at  れ .
# Loss is:  0.09046753385093508  at  1778  iteration(s) at  さ .
# Loss is:  0.08308544706859264  at  1779  iteration(s) at  び .
# Loss is:  0.08389931568146165  at  1780  iteration(s) at  は .
# Loss is:  0.026775998074471823  at  1781  iteration(s) at  せ .
# Loss is:  0.024655055916268657  at  1782  iteration(s) at  ほ .
# Loss is:  0.002115430631818878  at  1783  iteration(s) at  げ .
# Loss is:  0.03438274372651086  at  1784  iteration(s) at  む .
# Loss is:  0.049757836885979  at  1785  iteration(s) at  こ .
# Loss is:  0.5645766341536627  at  1786  iteration(s) at  ず .
# Loss is:  0.00028780807427949767  at  1787  iteration(s) at  が .
# Loss is:  0.12207762777614871  at  1788  iteration(s) at  べ .
# Loss is:  0.026822038215834454  at  1789  iteration(s) at  が .
# Loss is:  0.008560773959780988  at  1790  iteration(s) at  む .
# Loss is:  0.07644834863941971  at  1791  iteration(s) at  ゆ .
# Loss is:  0.0025690505240330915  at  1792  iteration(s) at  ば .
# Loss is:  0.016236329884851262  at  1793  iteration(s) at  み .
# Loss is:  0.119786548315698  at  1794  iteration(s) at  は .
# Loss is:  5.552834139346197e-05  at  1795  iteration(s) at  ん .
# Loss is:  0.005734705308826447  at  1796  iteration(s) at  る .
# Loss is:  0.01346547561184393  at  1797  iteration(s) at  も .
# Loss is:  0.12947145802045162  at  1798  iteration(s) at  げ .
# Loss is:  0.0008528886399522731  at  1799  iteration(s) at  ぢ .
# Loss is:  0.09505976574999869  at  1800  iteration(s) at  ざ .
# Loss is:  0.024973776436443666  at  1801  iteration(s) at  て .
# Loss is:  0.03533847266773037  at  1802  iteration(s) at  き .
# Loss is:  0.1196599070825438  at  1803  iteration(s) at  せ .
# Loss is:  0.15042652745441726  at  1804  iteration(s) at  ひ .
# Loss is:  0.011627222940155005  at  1805  iteration(s) at  ん .
# Loss is:  0.000602039875944408  at  1806  iteration(s) at  え .
# Loss is:  0.25835511070291955  at  1807  iteration(s) at  は .
# Loss is:  0.016647242190286134  at  1808  iteration(s) at  ず .
# Loss is:  0.010974331478384525  at  1809  iteration(s) at  で .
# Loss is:  0.05513038975807173  at  1810  iteration(s) at  る .
# Loss is:  0.00025064792187568847  at  1811  iteration(s) at  す .
# Loss is:  0.009988093214214504  at  1812  iteration(s) at  ち .
# Loss is:  0.004382927263964531  at  1813  iteration(s) at  ず .
# Loss is:  0.14594447540411964  at  1814  iteration(s) at  べ .
# Loss is:  0.017896912608424426  at  1815  iteration(s) at  だ .
# Loss is:  0.14376175563399704  at  1816  iteration(s) at  と .
# Loss is:  0.2536792299542946  at  1817  iteration(s) at  ね .
# Loss is:  0.06440568666979568  at  1818  iteration(s) at  ぴ .
# Loss is:  0.037566685800263185  at  1819  iteration(s) at  ち .
# Loss is:  0.024071796543047728  at  1820  iteration(s) at  だ .
# Loss is:  0.019904221756590377  at  1821  iteration(s) at  を .
# Loss is:  0.01556727481722877  at  1822  iteration(s) at  び .
# Loss is:  0.09246660003320063  at  1823  iteration(s) at  ふ .
# Loss is:  0.0018953757329476537  at  1824  iteration(s) at  ゆ .
# Loss is:  0.05076778087610105  at  1825  iteration(s) at  ね .
# Loss is:  0.0013833463052905352  at  1826  iteration(s) at  づ .
# Loss is:  0.06860722366873763  at  1827  iteration(s) at  つ .
# Loss is:  1.588041382946368  at  1828  iteration(s) at  ろ .
# Loss is:  0.0003759168862266896  at  1829  iteration(s) at  ど .
# Loss is:  0.00135472688368141  at  1830  iteration(s) at  じ .
# Loss is:  0.37592705613489286  at  1831  iteration(s) at  し .
# Loss is:  0.14093726109388913  at  1832  iteration(s) at  で .
# Loss is:  0.013233976581537972  at  1833  iteration(s) at  す .
# Loss is:  0.02841469017072997  at  1834  iteration(s) at  ぎ .
# Loss is:  0.02404109339500654  at  1835  iteration(s) at  を .
# Loss is:  0.3763088309796455  at  1836  iteration(s) at  こ .
# Loss is:  0.09324216322108288  at  1837  iteration(s) at  も .
# Loss is:  2.2161289488701335  at  1838  iteration(s) at  ぷ .
# Loss is:  0.0028113999506545148  at  1839  iteration(s) at  ぴ .
# Loss is:  0.2457337082595194  at  1840  iteration(s) at  さ .
# Loss is:  0.022474108245893954  at  1841  iteration(s) at  び .
# Loss is:  0.02469486336997912  at  1842  iteration(s) at  る .
# Loss is:  0.0329212140767066  at  1843  iteration(s) at  す .
# Loss is:  0.07808919938646432  at  1844  iteration(s) at  ぼ .
# Loss is:  0.05906046756473576  at  1845  iteration(s) at  る .
# Loss is:  1.1963384033594562  at  1846  iteration(s) at  ん .
# Loss is:  0.11726993036941448  at  1847  iteration(s) at  と .
# Loss is:  0.003274414142637878  at  1848  iteration(s) at  の .
# Loss is:  0.03006230698680903  at  1849  iteration(s) at  つ .
# Loss is:  0.014280856616828725  at  1850  iteration(s) at  そ .
# Loss is:  0.0780504177550755  at  1851  iteration(s) at  ぽ .
# Loss is:  0.036588695543303816  at  1852  iteration(s) at  り .
# Loss is:  0.018509306454186223  at  1853  iteration(s) at  ふ .
# Loss is:  0.018647318634431316  at  1854  iteration(s) at  と .
# Loss is:  0.006717672704565042  at  1855  iteration(s) at  わ .
# Loss is:  0.06975355805115506  at  1856  iteration(s) at  も .
# Loss is:  0.040729265779743486  at  1857  iteration(s) at  ぷ .
# Loss is:  0.025078355279062114  at  1858  iteration(s) at  ぬ .
# Loss is:  0.07196046566764437  at  1859  iteration(s) at  た .
# Loss is:  0.006979720527053557  at  1860  iteration(s) at  ま .
# Loss is:  3.709503997934806e-05  at  1861  iteration(s) at  あ .
# Loss is:  0.0035768203776418467  at  1862  iteration(s) at  お .
# Loss is:  0.15045987519201381  at  1863  iteration(s) at  せ .
# Loss is:  0.05358923340611165  at  1864  iteration(s) at  か .
# Loss is:  0.03120061795341244  at  1865  iteration(s) at  お .
# Loss is:  0.04795322705877223  at  1866  iteration(s) at  ん .
# Loss is:  0.03843698559590449  at  1867  iteration(s) at  に .
# Loss is:  0.02365242663410289  at  1868  iteration(s) at  づ .
# Loss is:  0.0777365376833651  at  1869  iteration(s) at  た .
# Loss is:  0.04907775394964937  at  1870  iteration(s) at  ひ .
# Loss is:  0.0631375050160398  at  1871  iteration(s) at  ど .
# Loss is:  0.04436010626494625  at  1872  iteration(s) at  み .
# Loss is:  0.6898156864146052  at  1873  iteration(s) at  ぐ .
# Loss is:  0.025618078131207006  at  1874  iteration(s) at  ざ .
# Loss is:  0.09649705250941626  at  1875  iteration(s) at  え .
# Loss is:  0.025587227461530797  at  1876  iteration(s) at  ざ .
# Loss is:  0.07094578755593264  at  1877  iteration(s) at  ゆ .
# Loss is:  3.290996021869089  at  1878  iteration(s) at  ご .
# Loss is:  0.04871920816528738  at  1879  iteration(s) at  ぢ .
# Loss is:  0.02275728724313246  at  1880  iteration(s) at  ぐ .
# Loss is:  0.1896560092641838  at  1881  iteration(s) at  い .
# Loss is:  0.026861098693573643  at  1882  iteration(s) at  め .
# Loss is:  0.09070397604178905  at  1883  iteration(s) at  へ .
# Loss is:  0.0651063322762869  at  1884  iteration(s) at  り .
# Loss is:  0.18856541572888322  at  1885  iteration(s) at  ぴ .
# Loss is:  0.12863947150682972  at  1886  iteration(s) at  い .
# Loss is:  0.005900004183482582  at  1887  iteration(s) at  い .
# Loss is:  0.6305573132655068  at  1888  iteration(s) at  く .
# Loss is:  0.04262761367870818  at  1889  iteration(s) at  わ .
# Loss is:  0.05306737041651777  at  1890  iteration(s) at  ぬ .
# Loss is:  0.021316632759575575  at  1891  iteration(s) at  つ .
# Loss is:  0.22219264174420805  at  1892  iteration(s) at  た .
# Loss is:  0.03642322490260346  at  1893  iteration(s) at  ざ .
# Loss is:  0.1015720238078068  at  1894  iteration(s) at  が .
# Loss is:  0.011243248852793958  at  1895  iteration(s) at  ま .
# Loss is:  0.01850546889083604  at  1896  iteration(s) at  さ .
# Loss is:  0.3884204452704356  at  1897  iteration(s) at  ぢ .
# Loss is:  0.04114522748506064  at  1898  iteration(s) at  ぼ .
# Loss is:  0.16561483307058852  at  1899  iteration(s) at  ゆ .
# Loss is:  0.01387021993889973  at  1900  iteration(s) at  へ .
# Loss is:  0.012958146721207287  at  1901  iteration(s) at  ま .
# Loss is:  0.042557576092888155  at  1902  iteration(s) at  は .
# Loss is:  0.018361587701416222  at  1903  iteration(s) at  ほ .
# Loss is:  0.01674021819390863  at  1904  iteration(s) at  ひ .
# Loss is:  0.09475222655141813  at  1905  iteration(s) at  る .
# Loss is:  0.06545961742118762  at  1906  iteration(s) at  え .
# Loss is:  5.004516032597323e-05  at  1907  iteration(s) at  ほ .
# Loss is:  0.014287154845542067  at  1908  iteration(s) at  ふ .
# Loss is:  0.05920058507783092  at  1909  iteration(s) at  す .
# Loss is:  0.00047276447978956016  at  1910  iteration(s) at  り .
# Loss is:  0.022682690411508895  at  1911  iteration(s) at  ぶ .
# Loss is:  0.0002745116814937871  at  1912  iteration(s) at  こ .
# Loss is:  0.07887365743703134  at  1913  iteration(s) at  ち .
# Loss is:  0.011016488400197807  at  1914  iteration(s) at  け .
# Loss is:  0.043505895375738686  at  1915  iteration(s) at  ぢ .
# Loss is:  0.010757015151933409  at  1916  iteration(s) at  ぴ .
# Loss is:  0.004004898564857604  at  1917  iteration(s) at  ま .
# Loss is:  0.016129258945170786  at  1918  iteration(s) at  す .
# Loss is:  0.021851290400684682  at  1919  iteration(s) at  ぷ .
# Loss is:  0.14020608181179628  at  1920  iteration(s) at  ぱ .
# Loss is:  0.17192629246011798  at  1921  iteration(s) at  べ .
# Loss is:  0.0019761308154614917  at  1922  iteration(s) at  ゆ .
# Loss is:  0.12474107457835497  at  1923  iteration(s) at  け .
# Loss is:  0.000781917615257383  at  1924  iteration(s) at  け .
# Loss is:  0.0107409004358246  at  1925  iteration(s) at  ぜ .
# Loss is:  0.0005684767616032202  at  1926  iteration(s) at  か .
# Loss is:  0.06815759895787189  at  1927  iteration(s) at  ね .
# Loss is:  0.0021123463520587803  at  1928  iteration(s) at  む .
# Loss is:  0.011536253910160069  at  1929  iteration(s) at  を .
# Loss is:  0.07253509015868138  at  1930  iteration(s) at  ざ .
# Loss is:  0.021144451372313525  at  1931  iteration(s) at  み .
# Loss is:  0.061231620774536935  at  1932  iteration(s) at  の .
# Loss is:  0.2584812791617303  at  1933  iteration(s) at  で .
# Loss is:  0.2282982532041838  at  1934  iteration(s) at  ぜ .
# Loss is:  0.02782437368098958  at  1935  iteration(s) at  く .
# Loss is:  0.07632185769483377  at  1936  iteration(s) at  ぢ .
# Loss is:  0.13376806605207975  at  1937  iteration(s) at  き .
# Loss is:  0.009692404665554795  at  1938  iteration(s) at  ろ .
# Loss is:  0.05819474055083541  at  1939  iteration(s) at  に .
# Loss is:  0.020562265854390055  at  1940  iteration(s) at  や .
# Loss is:  0.06639114047497369  at  1941  iteration(s) at  ご .
# Loss is:  0.006320829411582495  at  1942  iteration(s) at  こ .
# Loss is:  0.027420364245466147  at  1943  iteration(s) at  す .
# Loss is:  0.004767262196453218  at  1944  iteration(s) at  だ .
# Loss is:  0.051151916809518694  at  1945  iteration(s) at  ぐ .
# Loss is:  0.0013100597856612964  at  1946  iteration(s) at  こ .
# Loss is:  0.0029622151179470547  at  1947  iteration(s) at  ぜ .
# Loss is:  0.25793831097233066  at  1948  iteration(s) at  じ .
# Loss is:  0.06723014203859497  at  1949  iteration(s) at  つ .
# Loss is:  0.11514170307455415  at  1950  iteration(s) at  は .
# Loss is:  0.017965504976360534  at  1951  iteration(s) at  ぺ .
# Loss is:  0.002310883580464018  at  1952  iteration(s) at  ぞ .
# Loss is:  0.14667558959722923  at  1953  iteration(s) at  わ .
# Loss is:  0.07684190336734047  at  1954  iteration(s) at  ど .
# Loss is:  0.12105697119902972  at  1955  iteration(s) at  へ .
# Loss is:  0.020227634694927627  at  1956  iteration(s) at  と .
# Loss is:  0.0007954447802890186  at  1957  iteration(s) at  ん .
# Loss is:  0.006055160513414616  at  1958  iteration(s) at  な .
# Loss is:  0.00019958890626208846  at  1959  iteration(s) at  ぴ .
# Loss is:  2.6690133218559885e-05  at  1960  iteration(s) at  ま .
# Loss is:  0.027041050588182784  at  1961  iteration(s) at  に .
# Loss is:  0.0033148339931699388  at  1962  iteration(s) at  ま .
# Loss is:  0.02865419323087816  at  1963  iteration(s) at  な .
# Loss is:  0.08857902308622047  at  1964  iteration(s) at  ふ .
# Loss is:  0.003344037337322842  at  1965  iteration(s) at  へ .
# Loss is:  0.0006398124178143484  at  1966  iteration(s) at  ず .
# Loss is:  0.014109885916539694  at  1967  iteration(s) at  ろ .
# Loss is:  0.065710540046206  at  1968  iteration(s) at  べ .
# Loss is:  0.021976194781773952  at  1969  iteration(s) at  こ .
# Loss is:  0.15795765775110715  at  1970  iteration(s) at  ぷ .
# Loss is:  0.012879887227226144  at  1971  iteration(s) at  か .
# Loss is:  0.027800845324669556  at  1972  iteration(s) at  ご .
# Loss is:  0.016508297994492556  at  1973  iteration(s) at  れ .
# Loss is:  0.034671229232268425  at  1974  iteration(s) at  り .
# Loss is:  0.17415999739048654  at  1975  iteration(s) at  ば .
# Loss is:  0.18136777209410865  at  1976  iteration(s) at  こ .
# Loss is:  0.07251845333836021  at  1977  iteration(s) at  ひ .
# Loss is:  0.03829100196273294  at  1978  iteration(s) at  や .
# Loss is:  0.003496721124038062  at  1979  iteration(s) at  げ .
# Loss is:  0.031884670059876934  at  1980  iteration(s) at  さ .
# Loss is:  0.0728209295489775  at  1981  iteration(s) at  び .
# Loss is:  0.012646093048800287  at  1982  iteration(s) at  い .
# Loss is:  0.013624563097858474  at  1983  iteration(s) at  そ .
# Loss is:  0.043442114041726244  at  1984  iteration(s) at  ぼ .
# Loss is:  0.005614599851392862  at  1985  iteration(s) at  ぐ .
# Loss is:  0.010130446295999409  at  1986  iteration(s) at  ふ .
# Loss is:  3.125450916929712e-05  at  1987  iteration(s) at  ぱ .
# Loss is:  0.0471616237639971  at  1988  iteration(s) at  そ .
# Loss is:  0.018147090431235326  at  1989  iteration(s) at  こ .
# Loss is:  0.058991572900011065  at  1990  iteration(s) at  ぎ .
# Loss is:  0.24090567867860993  at  1991  iteration(s) at  を .
# Loss is:  0.07957102425821395  at  1992  iteration(s) at  ぐ .
# Loss is:  0.00806274250806556  at  1993  iteration(s) at  わ .
# Loss is:  0.046276749736618446  at  1994  iteration(s) at  げ .
# Loss is:  0.0024473110650365024  at  1995  iteration(s) at  ぼ .
# Loss is:  0.018034202686507877  at  1996  iteration(s) at  に .
# Loss is:  0.08237171959023572  at  1997  iteration(s) at  ぞ .
# Loss is:  0.1028325713868542  at  1998  iteration(s) at  へ .
# Loss is:  0.07683319484117274  at  1999  iteration(s) at  ゆ .
# Loss is:  0.11512993109152675  at  2000  iteration(s) at  で .
# Loss is:  0.0013645209665302442  at  2001  iteration(s) at  ぎ .
# Loss is:  7.463636645534969e-06  at  2002  iteration(s) at  と .
# Loss is:  0.006203043541162349  at  2003  iteration(s) at  す .
# Loss is:  0.039154937486497836  at  2004  iteration(s) at  を .
# Loss is:  0.07880947509633515  at  2005  iteration(s) at  も .
# Loss is:  0.03200677138087844  at  2006  iteration(s) at  け .
# Loss is:  0.12361392944110318  at  2007  iteration(s) at  ぺ .
# Loss is:  0.0025209056592608637  at  2008  iteration(s) at  る .
# Loss is:  0.049204419104312905  at  2009  iteration(s) at  ふ .
# Loss is:  0.1456206274003339  at  2010  iteration(s) at  へ .
# Loss is:  0.05138963823179169  at  2011  iteration(s) at  む .
# Loss is:  0.04366155916687243  at  2012  iteration(s) at  り .
# Loss is:  0.02153276178896263  at  2013  iteration(s) at  ま .
# Loss is:  0.2647153579176287  at  2014  iteration(s) at  た .
# Loss is:  0.28606971130427644  at  2015  iteration(s) at  つ .
# Loss is:  0.07224335035092229  at  2016  iteration(s) at  と .
# Loss is:  0.03750748479230176  at  2017  iteration(s) at  じ .
# Loss is:  0.1368934953027774  at  2018  iteration(s) at  ぽ .
# Loss is:  0.021136738087257495  at  2019  iteration(s) at  め .
# Loss is:  4.4755227494290185e-05  at  2020  iteration(s) at  わ .
# Loss is:  0.028489542581903168  at  2021  iteration(s) at  ね .
# Loss is:  0.02934554300955966  at  2022  iteration(s) at  む .
# Loss is:  0.05837687975262946  at  2023  iteration(s) at  ま .
# Loss is:  0.35357993165907137  at  2024  iteration(s) at  く .
# Loss is:  0.0011088037222498663  at  2025  iteration(s) at  ぜ .
# Loss is:  0.015071561934051928  at  2026  iteration(s) at  い .
# Loss is:  0.0247336539737574  at  2027  iteration(s) at  づ .
# Loss is:  0.003233175803537678  at  2028  iteration(s) at  ひ .
# Loss is:  0.0035332973021741263  at  2029  iteration(s) at  す .
# Loss is:  0.021415239869937316  at  2030  iteration(s) at  ぽ .
# Loss is:  0.053397300903509484  at  2031  iteration(s) at  れ .
# Loss is:  0.03192169784914428  at  2032  iteration(s) at  り .
# Loss is:  0.0044786292592049  at  2033  iteration(s) at  や .
# Loss is:  0.0031653038631968204  at  2034  iteration(s) at  れ .
# Loss is:  0.03747599797450271  at  2035  iteration(s) at  ぷ .
# Loss is:  0.0013695484178653415  at  2036  iteration(s) at  は .
# Loss is:  0.01986920590965941  at  2037  iteration(s) at  で .
# Loss is:  0.006204353601333952  at  2038  iteration(s) at  お .
# Loss is:  0.048134110845617785  at  2039  iteration(s) at  ろ .
# Loss is:  0.1587622014933344  at  2040  iteration(s) at  ね .
# Loss is:  0.01398484926552924  at  2041  iteration(s) at  さ .
# Loss is:  0.057209269120135624  at  2042  iteration(s) at  べ .
# Loss is:  0.014923875710805171  at  2043  iteration(s) at  り .
# Loss is:  0.01868960357104834  at  2044  iteration(s) at  ぬ .
# Loss is:  0.023609076727061272  at  2045  iteration(s) at  ぬ .
# Loss is:  0.004670731448661161  at  2046  iteration(s) at  み .
# Loss is:  0.030305047417171695  at  2047  iteration(s) at  ず .
# Loss is:  0.0033933403385160354  at  2048  iteration(s) at  た .
# Loss is:  0.007344766486340626  at  2049  iteration(s) at  て .
# Loss is:  0.04018705698630105  at  2050  iteration(s) at  ぱ .
# Loss is:  0.020995699015005646  at  2051  iteration(s) at  づ .
# Loss is:  0.09042693471328142  at  2052  iteration(s) at  ふ .
# Loss is:  0.04669101599655462  at  2053  iteration(s) at  お .
# Loss is:  0.10037630579022468  at  2054  iteration(s) at  よ .
# Loss is:  0.357042533861745  at  2055  iteration(s) at  ぞ .
# Loss is:  0.032658327700360784  at  2056  iteration(s) at  い .
# Loss is:  0.02253297903536527  at  2057  iteration(s) at  ぺ .
# Loss is:  0.15494530774974152  at  2058  iteration(s) at  び .
# Loss is:  0.011480805128762001  at  2059  iteration(s) at  に .
# Loss is:  0.019427569942399334  at  2060  iteration(s) at  ち .
# Loss is:  0.06352365100265799  at  2061  iteration(s) at  け .
# Loss is:  9.148001498268351e-05  at  2062  iteration(s) at  や .
# Loss is:  0.028726472253792882  at  2063  iteration(s) at  な .
# Loss is:  0.03098619099364066  at  2064  iteration(s) at  ぶ .
# Loss is:  0.05363971217409401  at  2065  iteration(s) at  ま .
# Loss is:  0.01874752594213914  at  2066  iteration(s) at  し .
# Loss is:  0.330372725363162  at  2067  iteration(s) at  つ .
# Loss is:  0.01897986340405794  at  2068  iteration(s) at  そ .
# Loss is:  0.0004190970161646796  at  2069  iteration(s) at  え .
# Loss is:  0.08333434259841889  at  2070  iteration(s) at  や .
# Loss is:  0.012838228794367421  at  2071  iteration(s) at  み .
# Loss is:  0.010286943346450158  at  2072  iteration(s) at  ぺ .
# Loss is:  0.002399222358710197  at  2073  iteration(s) at  け .
# Loss is:  0.17370704140185703  at  2074  iteration(s) at  わ .
# Loss is:  0.004292661117607203  at  2075  iteration(s) at  お .
# Loss is:  0.005043989129169735  at  2076  iteration(s) at  ぱ .
# Loss is:  0.1519848346436125  at  2077  iteration(s) at  る .
# Loss is:  1.1761954088584943  at  2078  iteration(s) at  き .
# Loss is:  0.04446165986362032  at  2079  iteration(s) at  め .
# Loss is:  0.1253107401530063  at  2080  iteration(s) at  ぽ .
# Loss is:  0.0006821811984908481  at  2081  iteration(s) at  ぺ .
# Loss is:  0.07495791696533839  at  2082  iteration(s) at  け .
# Loss is:  0.06802247414415034  at  2083  iteration(s) at  め .
# Loss is:  0.00981809226546021  at  2084  iteration(s) at  う .
# Loss is:  0.1138084838891504  at  2085  iteration(s) at  じ .
# Loss is:  0.08496226580702683  at  2086  iteration(s) at  が .
# Loss is:  0.00819293014423124  at  2087  iteration(s) at  ぞ .
# Loss is:  0.034236681946378765  at  2088  iteration(s) at  り .
# Loss is:  0.07118696140632581  at  2089  iteration(s) at  ふ .
# Loss is:  0.0050741176244328764  at  2090  iteration(s) at  ば .
# Loss is:  0.01858588260867141  at  2091  iteration(s) at  だ .
# Loss is:  0.08476764563720536  at  2092  iteration(s) at  ん .
# Loss is:  0.2203359393375047  at  2093  iteration(s) at  が .
# Loss is:  0.009092495188074272  at  2094  iteration(s) at  ん .
# Loss is:  0.06470984953245476  at  2095  iteration(s) at  ぞ .
# Loss is:  0.04780077000816484  at  2096  iteration(s) at  づ .
# Loss is:  0.10604524198946935  at  2097  iteration(s) at  べ .
# Loss is:  0.16502638379957207  at  2098  iteration(s) at  ぺ .
# Loss is:  0.021215397274632997  at  2099  iteration(s) at  あ .
# Loss is:  0.03844393666625633  at  2100  iteration(s) at  を .
# Loss is:  0.048058822917282806  at  2101  iteration(s) at  ざ .
# Loss is:  0.040652732167576186  at  2102  iteration(s) at  か .
# Loss is:  0.08297122527411396  at  2103  iteration(s) at  み .
# Loss is:  6.048157442408596e-05  at  2104  iteration(s) at  へ .
# Loss is:  0.01115127791981511  at  2105  iteration(s) at  ぶ .
# Loss is:  0.14865793124001264  at  2106  iteration(s) at  ぺ .
# Loss is:  0.06873509292104268  at  2107  iteration(s) at  ぼ .
# Loss is:  0.0008932789536778739  at  2108  iteration(s) at  ひ .
# Loss is:  0.05486706614202352  at  2109  iteration(s) at  さ .
# Loss is:  0.022822937603534866  at  2110  iteration(s) at  ど .
# Loss is:  0.006875576982776769  at  2111  iteration(s) at  べ .
# Loss is:  0.020120193043773483  at  2112  iteration(s) at  あ .
# Loss is:  0.10653508897093401  at  2113  iteration(s) at  を .
# Loss is:  0.04861510981671078  at  2114  iteration(s) at  さ .
# Loss is:  0.0013501361028746973  at  2115  iteration(s) at  が .
# Loss is:  0.10784948772118828  at  2116  iteration(s) at  ぺ .
# Loss is:  0.056743965057360464  at  2117  iteration(s) at  ぺ .
# Loss is:  0.005784465855875602  at  2118  iteration(s) at  あ .
# Loss is:  0.0032932268893302355  at  2119  iteration(s) at  ね .
# Loss is:  0.07916816417353387  at  2120  iteration(s) at  は .
# Loss is:  0.1597050986372194  at  2121  iteration(s) at  ぞ .
# Loss is:  0.1450425913767296  at  2122  iteration(s) at  ず .
# Loss is:  0.013399861136071342  at  2123  iteration(s) at  わ .
# Loss is:  0.014145817194521822  at  2124  iteration(s) at  お .
# Loss is:  0.09203257731675246  at  2125  iteration(s) at  で .
# Loss is:  0.03746993536615288  at  2126  iteration(s) at  ふ .
# Loss is:  0.01659177369341694  at  2127  iteration(s) at  し .
# Loss is:  0.15928894384419265  at  2128  iteration(s) at  で .
# Loss is:  0.0005501418046107888  at  2129  iteration(s) at  ず .
# Loss at epoch =  0.07858601922846435
# Epoch  18  completed.
# Loss is:  0.012942429496212804  at  0  iteration(s) at  ど .
# Loss is:  1.2809778004328933  at  1  iteration(s) at  い .
# Loss is:  0.016103839196816887  at  2  iteration(s) at  ひ .
# Loss is:  0.08613405515997458  at  3  iteration(s) at  ぞ .
# Loss is:  0.020555722512611237  at  4  iteration(s) at  す .
# Loss is:  0.013338885507994856  at  5  iteration(s) at  せ .
# Loss is:  0.004256833508526161  at  6  iteration(s) at  く .
# Loss is:  0.003922939704191701  at  7  iteration(s) at  ふ .
# Loss is:  0.00012708403671190518  at  8  iteration(s) at  う .
# Loss is:  0.031379480802225884  at  9  iteration(s) at  き .
# Loss is:  0.0036546177319358676  at  10  iteration(s) at  ぐ .
# Loss is:  0.029198679980664968  at  11  iteration(s) at  ぜ .
# Loss is:  0.02406634580000738  at  12  iteration(s) at  か .
# Loss is:  0.025485869093923516  at  13  iteration(s) at  れ .
# Loss is:  0.0012538346613333664  at  14  iteration(s) at  わ .
# Loss is:  0.010603312466878201  at  15  iteration(s) at  ほ .
# Loss is:  0.11239626520272694  at  16  iteration(s) at  を .
# Loss is:  0.029049193800790796  at  17  iteration(s) at  ら .
# Loss is:  0.14511270622344466  at  18  iteration(s) at  ぞ .
# Loss is:  0.2175233660203106  at  19  iteration(s) at  つ .
# Loss is:  0.03389590373996943  at  20  iteration(s) at  ぽ .
# Loss is:  0.0487197388933284  at  21  iteration(s) at  じ .
# Loss is:  0.040777897655951544  at  22  iteration(s) at  ち .
# Loss is:  0.005409230481548943  at  23  iteration(s) at  え .
# Loss is:  0.0027365757483840793  at  24  iteration(s) at  て .
# Loss is:  0.051577023283592614  at  25  iteration(s) at  あ .
# Loss is:  0.001122145704083076  at  26  iteration(s) at  め .
# Loss is:  0.03602700706214095  at  27  iteration(s) at  を .
# Loss is:  0.09512927225372105  at  28  iteration(s) at  け .
# Loss is:  0.00014864251649282048  at  29  iteration(s) at  ゆ .
# Loss is:  0.03918191856460309  at  30  iteration(s) at  ぷ .
# Loss is:  0.0001362933938850108  at  31  iteration(s) at  み .
# Loss is:  0.0027063211371614495  at  32  iteration(s) at  り .
# Loss is:  0.052268465121629505  at  33  iteration(s) at  ぽ .
# ...
# Loss is:  0.02193068313959334  at  1876  iteration(s) at  ざ .
# Loss is:  0.06068597983304145  at  1877  iteration(s) at  ゆ .
# Loss is:  3.143468049441537  at  1878  iteration(s) at  ご .
# Loss is:  0.04288394281193653  at  1879  iteration(s) at  ぢ .
# Loss is:  0.019819760763183574  at  1880  iteration(s) at  ぐ .
# Loss is:  0.16540928178007708  at  1881  iteration(s) at  い .
# Loss is:  0.02328615997017384  at  1882  iteration(s) at  め .
# Loss is:  0.0811212931981621  at  1883  iteration(s) at  へ .
# Loss is:  0.05507299104860057  at  1884  iteration(s) at  り .
# Loss is:  0.16096025858442073  at  1885  iteration(s) at  ぴ .
# Loss is:  0.11400116604049737  at  1886  iteration(s) at  い .
# Loss is:  0.004930560060438969  at  1887  iteration(s) at  い .
# Loss is:  0.5565927877325577  at  1888  iteration(s) at  く .
# Loss is:  0.040743427707350476  at  1889  iteration(s) at  わ .
# Loss is:  0.04733591946094975  at  1890  iteration(s) at  ぬ .
# Loss is:  0.018351410518452967  at  1891  iteration(s) at  つ .
# Loss is:  0.1873660661644111  at  1892  iteration(s) at  た .
# Loss is:  0.031294910082247086  at  1893  iteration(s) at  ざ .
# Loss is:  0.08898230681014159  at  1894  iteration(s) at  が .
# Loss is:  0.010747183058579567  at  1895  iteration(s) at  ま .
# Loss is:  0.016409084835584904  at  1896  iteration(s) at  さ .
# Loss is:  0.3112651536649831  at  1897  iteration(s) at  ぢ .
# Loss is:  0.03584510147549313  at  1898  iteration(s) at  ぼ .
# Loss is:  0.1414760694128004  at  1899  iteration(s) at  ゆ .
# Loss is:  0.011713642590587634  at  1900  iteration(s) at  へ .
# Loss is:  0.012669643757895583  at  1901  iteration(s) at  ま .
# Loss is:  0.04158525209044322  at  1902  iteration(s) at  は .
# Loss is:  0.016546737162528354  at  1903  iteration(s) at  ほ .
# Loss is:  0.01531572623704579  at  1904  iteration(s) at  ひ .
# Loss is:  0.08183231997978152  at  1905  iteration(s) at  る .
# Loss is:  0.05517080825940884  at  1906  iteration(s) at  え .
# Loss is:  3.97501100575242e-05  at  1907  iteration(s) at  ほ .
# Loss is:  0.013422273238328753  at  1908  iteration(s) at  ふ .
# Loss is:  0.05041265127950348  at  1909  iteration(s) at  す .
# Loss is:  0.0003813430894116071  at  1910  iteration(s) at  り .
# Loss is:  0.020800051876627968  at  1911  iteration(s) at  ぶ .
# Loss is:  0.00026199624083566507  at  1912  iteration(s) at  こ .
# Loss is:  0.06242086300683807  at  1913  iteration(s) at  ち .
# Loss is:  0.010328976929835202  at  1914  iteration(s) at  け .
# Loss is:  0.03909304870419846  at  1915  iteration(s) at  ぢ .
# Loss is:  0.009106772635854167  at  1916  iteration(s) at  ぴ .
# Loss is:  0.0036320117684530166  at  1917  iteration(s) at  ま .
# Loss is:  0.013831527714043845  at  1918  iteration(s) at  す .
# Loss is:  0.0170558246380569  at  1919  iteration(s) at  ぷ .
# Loss is:  0.12209915671714479  at  1920  iteration(s) at  ぱ .
# Loss is:  0.14991439584178043  at  1921  iteration(s) at  べ .
# Loss is:  0.001785072898907279  at  1922  iteration(s) at  ゆ .
# Loss is:  0.11085472721746302  at  1923  iteration(s) at  け .
# Loss is:  0.0006977663319225948  at  1924  iteration(s) at  け .
# Loss is:  0.009986474197110103  at  1925  iteration(s) at  ぜ .
# Loss is:  0.0005231899395794068  at  1926  iteration(s) at  か .
# Loss is:  0.05756502899762172  at  1927  iteration(s) at  ね .
# Loss is:  0.001832461320032418  at  1928  iteration(s) at  む .
# Loss is:  0.009741878012098555  at  1929  iteration(s) at  を .
# Loss is:  0.057514593940746046  at  1930  iteration(s) at  ざ .
# Loss is:  0.018833193711575207  at  1931  iteration(s) at  み .
# Loss is:  0.052358350512962525  at  1932  iteration(s) at  の .
# Loss is:  0.2147467050909809  at  1933  iteration(s) at  で .
# Loss is:  0.19900042068408919  at  1934  iteration(s) at  ぜ .
# Loss is:  0.029501056185490596  at  1935  iteration(s) at  く .
# Loss is:  0.06725139068545939  at  1936  iteration(s) at  ぢ .
# Loss is:  0.11772537207388259  at  1937  iteration(s) at  き .
# Loss is:  0.008547877335811757  at  1938  iteration(s) at  ろ .
# Loss is:  0.049038488259671005  at  1939  iteration(s) at  に .
# Loss is:  0.01770567849352458  at  1940  iteration(s) at  や .
# Loss is:  0.06061934756984854  at  1941  iteration(s) at  ご .
# Loss is:  0.0051634277861065826  at  1942  iteration(s) at  こ .
# Loss is:  0.02389839715587734  at  1943  iteration(s) at  す .
# Loss is:  0.0037016505874332513  at  1944  iteration(s) at  だ .
# Loss is:  0.046833522718202264  at  1945  iteration(s) at  ぐ .
# Loss is:  0.001027107060089152  at  1946  iteration(s) at  こ .
# Loss is:  0.002538889302553863  at  1947  iteration(s) at  ぜ .
# Loss is:  0.21386291149552725  at  1948  iteration(s) at  じ .
# Loss is:  0.05609769323666755  at  1949  iteration(s) at  つ .
# Loss is:  0.09270817444218594  at  1950  iteration(s) at  は .
# Loss is:  0.01501840687082271  at  1951  iteration(s) at  ぺ .
# Loss is:  0.001927762063294422  at  1952  iteration(s) at  ぞ .
# Loss is:  0.12456371599813755  at  1953  iteration(s) at  わ .
# Loss is:  0.06822645446605573  at  1954  iteration(s) at  ど .
# Loss is:  0.10196689623220934  at  1955  iteration(s) at  へ .
# Loss is:  0.018501981040364802  at  1956  iteration(s) at  と .
# Loss is:  0.0006077075546643756  at  1957  iteration(s) at  ん .
# Loss is:  0.005809075653041461  at  1958  iteration(s) at  な .
# Loss is:  0.00016859907617546637  at  1959  iteration(s) at  ぴ .
# Loss is:  1.7194893559923098e-05  at  1960  iteration(s) at  ま .
# Loss is:  0.024987375638070384  at  1961  iteration(s) at  に .
# Loss is:  0.0029713214246139337  at  1962  iteration(s) at  ま .
# Loss is:  0.026294605370956632  at  1963  iteration(s) at  な .
# Loss is:  0.07795101917924793  at  1964  iteration(s) at  ふ .
# Loss is:  0.0028988553965081094  at  1965  iteration(s) at  へ .
# Loss is:  0.0006287200116319013  at  1966  iteration(s) at  ず .
# Loss is:  0.012856137119158022  at  1967  iteration(s) at  ろ .
# Loss is:  0.060901941235327085  at  1968  iteration(s) at  べ .
# Loss is:  0.018132128445352974  at  1969  iteration(s) at  こ .
# Loss is:  0.137891658195933  at  1970  iteration(s) at  ぷ .
# Loss is:  0.011723050146476515  at  1971  iteration(s) at  か .
# Loss is:  0.022754012448731112  at  1972  iteration(s) at  ご .
# Loss is:  0.014555764542197386  at  1973  iteration(s) at  れ .
# Loss is:  0.02975418970934978  at  1974  iteration(s) at  り .
# Loss is:  0.14768333668649855  at  1975  iteration(s) at  ば .
# Loss is:  0.15089007696739618  at  1976  iteration(s) at  こ .
# Loss is:  0.06252232888651689  at  1977  iteration(s) at  ひ .
# Loss is:  0.03426877943332616  at  1978  iteration(s) at  や .
# Loss is:  0.0032129628304637956  at  1979  iteration(s) at  げ .
# Loss is:  0.028747413440932394  at  1980  iteration(s) at  さ .
# Loss is:  0.06555304636582883  at  1981  iteration(s) at  び .
# Loss is:  0.01149743642610637  at  1982  iteration(s) at  い .
# Loss is:  0.012588896853153  at  1983  iteration(s) at  そ .
# Loss is:  0.0390699432667614  at  1984  iteration(s) at  ぼ .
# Loss is:  0.004703269976712757  at  1985  iteration(s) at  ぐ .
# Loss is:  0.009902540446293873  at  1986  iteration(s) at  ふ .
# Loss is:  3.0267378427476526e-05  at  1987  iteration(s) at  ぱ .
# Loss is:  0.03953113313944984  at  1988  iteration(s) at  そ .
# Loss is:  0.01525736560038101  at  1989  iteration(s) at  こ .
# Loss is:  0.05131800417507109  at  1990  iteration(s) at  ぎ .
# Loss is:  0.2030398174777011  at  1991  iteration(s) at  を .
# Loss is:  0.0701082093924161  at  1992  iteration(s) at  ぐ .
# Loss is:  0.007294828739552375  at  1993  iteration(s) at  わ .
# Loss is:  0.0416304306179496  at  1994  iteration(s) at  げ .
# Loss is:  0.0023822978982986076  at  1995  iteration(s) at  ぼ .
# Loss is:  0.01717908303273803  at  1996  iteration(s) at  に .
# Loss is:  0.07026585108810772  at  1997  iteration(s) at  ぞ .
# Loss is:  0.08801364555651794  at  1998  iteration(s) at  へ .
# Loss is:  0.06636614954500514  at  1999  iteration(s) at  ゆ .
# Loss is:  0.09843694678821718  at  2000  iteration(s) at  で .
# Loss is:  0.0011841764041904627  at  2001  iteration(s) at  ぎ .
# Loss is:  5.999831738231384e-06  at  2002  iteration(s) at  と .
# Loss is:  0.005380684732460804  at  2003  iteration(s) at  す .
# Loss is:  0.033642986774783376  at  2004  iteration(s) at  を .
# Loss is:  0.07186150021088132  at  2005  iteration(s) at  も .
# Loss is:  0.028724241314622277  at  2006  iteration(s) at  け .
# Loss is:  0.10576698331097635  at  2007  iteration(s) at  ぺ .
# Loss is:  0.0022987758552987466  at  2008  iteration(s) at  る .
# Loss is:  0.04387798272258157  at  2009  iteration(s) at  ふ .
# Loss is:  0.1227084370181436  at  2010  iteration(s) at  へ .
# Loss is:  0.04519589844136749  at  2011  iteration(s) at  む .
# Loss is:  0.03792850798791486  at  2012  iteration(s) at  り .
# Loss is:  0.01832094270905384  at  2013  iteration(s) at  ま .
# Loss is:  0.23481006524518297  at  2014  iteration(s) at  た .
# Loss is:  0.2440052615910551  at  2015  iteration(s) at  つ .
# Loss is:  0.06367313646097017  at  2016  iteration(s) at  と .
# Loss is:  0.035167411654861855  at  2017  iteration(s) at  じ .
# Loss is:  0.1215812439860185  at  2018  iteration(s) at  ぽ .
# Loss is:  0.018703827922292644  at  2019  iteration(s) at  め .
# Loss is:  3.6936897238953165e-05  at  2020  iteration(s) at  わ .
# Loss is:  0.02529061263007691  at  2021  iteration(s) at  ね .
# Loss is:  0.025652400864307024  at  2022  iteration(s) at  む .
# Loss is:  0.05066343164857929  at  2023  iteration(s) at  ま .
# Loss is:  0.2987570487697027  at  2024  iteration(s) at  く .
# Loss is:  0.0009653862452209044  at  2025  iteration(s) at  ぜ .
# Loss is:  0.014181522401712441  at  2026  iteration(s) at  い .
# Loss is:  0.02241409605438458  at  2027  iteration(s) at  づ .
# Loss is:  0.0027622041849881852  at  2028  iteration(s) at  ひ .
# Loss is:  0.002971862845485921  at  2029  iteration(s) at  す .
# Loss is:  0.01773865049847479  at  2030  iteration(s) at  ぽ .
# Loss is:  0.047209351817613716  at  2031  iteration(s) at  れ .
# Loss is:  0.027467367129456778  at  2032  iteration(s) at  り .
# Loss is:  0.0038559035863412606  at  2033  iteration(s) at  や .
# Loss is:  0.00267122234303153  at  2034  iteration(s) at  れ .
# Loss is:  0.0332149907014334  at  2035  iteration(s) at  ぷ .
# Loss is:  0.0013099700782752046  at  2036  iteration(s) at  は .
# Loss is:  0.016776889279395364  at  2037  iteration(s) at  で .
# Loss is:  0.005398573792906367  at  2038  iteration(s) at  お .
# Loss is:  0.04290929201833997  at  2039  iteration(s) at  ろ .
# Loss is:  0.1354472013215433  at  2040  iteration(s) at  ね .
# Loss is:  0.01441158192606371  at  2041  iteration(s) at  さ .
# Loss is:  0.05271120959738883  at  2042  iteration(s) at  べ .
# Loss is:  0.012963608451030978  at  2043  iteration(s) at  り .
# Loss is:  0.016782860416953257  at  2044  iteration(s) at  ぬ .
# Loss is:  0.022601719856042087  at  2045  iteration(s) at  ぬ .
# Loss is:  0.004555127187934645  at  2046  iteration(s) at  み .
# Loss is:  0.027115832568703212  at  2047  iteration(s) at  ず .
# Loss is:  0.003892638488446463  at  2048  iteration(s) at  た .
# Loss is:  0.006098097075231404  at  2049  iteration(s) at  て .
# Loss is:  0.03629531455857274  at  2050  iteration(s) at  ぱ .
# Loss is:  0.01953226587960625  at  2051  iteration(s) at  づ .
# Loss is:  0.07673414738135409  at  2052  iteration(s) at  ふ .
# Loss is:  0.03911654462116619  at  2053  iteration(s) at  お .
# Loss is:  0.08587808294642045  at  2054  iteration(s) at  よ .
# Loss is:  0.2916137560649165  at  2055  iteration(s) at  ぞ .
# Loss is:  0.027753302785099812  at  2056  iteration(s) at  い .
# Loss is:  0.018809011205729715  at  2057  iteration(s) at  ぺ .
# Loss is:  0.12990306304624571  at  2058  iteration(s) at  び .
# Loss is:  0.009220131116496682  at  2059  iteration(s) at  に .
# Loss is:  0.015573460689230673  at  2060  iteration(s) at  ち .
# Loss is:  0.05703302723749094  at  2061  iteration(s) at  け .
# Loss is:  7.318321811220436e-05  at  2062  iteration(s) at  や .
# Loss is:  0.02473141432076336  at  2063  iteration(s) at  な .
# Loss is:  0.026484799313027253  at  2064  iteration(s) at  ぶ .
# Loss is:  0.04708931665077582  at  2065  iteration(s) at  ま .
# Loss is:  0.016499011760893526  at  2066  iteration(s) at  し .
# Loss is:  0.26567615717904575  at  2067  iteration(s) at  つ .
# Loss is:  0.017052266128110793  at  2068  iteration(s) at  そ .
# Loss is:  0.00035907909260821314  at  2069  iteration(s) at  え .
# Loss is:  0.06837385143087547  at  2070  iteration(s) at  や .
# Loss is:  0.011133477215165955  at  2071  iteration(s) at  み .
# Loss is:  0.008714219430100192  at  2072  iteration(s) at  ぺ .
# Loss is:  0.0020949995324568236  at  2073  iteration(s) at  け .
# Loss is:  0.14977546928428775  at  2074  iteration(s) at  わ .
# Loss is:  0.0036661504006075974  at  2075  iteration(s) at  お .
# Loss is:  0.004056143288290315  at  2076  iteration(s) at  ぱ .
# Loss is:  0.13390352065623828  at  2077  iteration(s) at  る .
# Loss is:  0.998293403736805  at  2078  iteration(s) at  き .
# Loss is:  0.040897487177399196  at  2079  iteration(s) at  め .
# Loss is:  0.10451492106771429  at  2080  iteration(s) at  ぽ .
# Loss is:  0.0005411703213182897  at  2081  iteration(s) at  ぺ .
# Loss is:  0.06800485394771873  at  2082  iteration(s) at  け .
# Loss is:  0.0610747391760495  at  2083  iteration(s) at  め .
# Loss is:  0.008833950387211936  at  2084  iteration(s) at  う .
# Loss is:  0.09622899904548264  at  2085  iteration(s) at  じ .
# Loss is:  0.07065322594508712  at  2086  iteration(s) at  が .
# Loss is:  0.006664208106136755  at  2087  iteration(s) at  ぞ .
# Loss is:  0.030251292160892083  at  2088  iteration(s) at  り .
# Loss is:  0.06369573192680218  at  2089  iteration(s) at  ふ .
# Loss is:  0.00392065527585607  at  2090  iteration(s) at  ば .
# Loss is:  0.016078760092826442  at  2091  iteration(s) at  だ .
# Loss is:  0.07551595096237981  at  2092  iteration(s) at  ん .
# Loss is:  0.18651950095508404  at  2093  iteration(s) at  が .
# Loss is:  0.007141019600101209  at  2094  iteration(s) at  ん .
# Loss is:  0.05966965882031503  at  2095  iteration(s) at  ぞ .
# Loss is:  0.04123650391062346  at  2096  iteration(s) at  づ .
# Loss is:  0.10277672985638223  at  2097  iteration(s) at  べ .
# Loss is:  0.13813082755977033  at  2098  iteration(s) at  ぺ .
# Loss is:  0.017931419748163143  at  2099  iteration(s) at  あ .
# Loss is:  0.03288981609562922  at  2100  iteration(s) at  を .
# Loss is:  0.04253935224731254  at  2101  iteration(s) at  ざ .
# Loss is:  0.03559781813583051  at  2102  iteration(s) at  か .
# Loss is:  0.07285109966937128  at  2103  iteration(s) at  み .
# Loss is:  5.2369149093508345e-05  at  2104  iteration(s) at  へ .
# Loss is:  0.00977065082943419  at  2105  iteration(s) at  ぶ .
# Loss is:  0.12120560210672375  at  2106  iteration(s) at  ぺ .
# Loss is:  0.06199867124832466  at  2107  iteration(s) at  ぼ .
# Loss is:  0.0007705676982252803  at  2108  iteration(s) at  ひ .
# Loss is:  0.04725814772267803  at  2109  iteration(s) at  さ .
# Loss is:  0.02140068413064257  at  2110  iteration(s) at  ど .
# Loss is:  0.006117323821955862  at  2111  iteration(s) at  べ .
# Loss is:  0.01762258770083713  at  2112  iteration(s) at  あ .
# Loss is:  0.08976608077981853  at  2113  iteration(s) at  を .
# Loss is:  0.042904629639212245  at  2114  iteration(s) at  さ .
# Loss is:  0.0012590820130973781  at  2115  iteration(s) at  が .
# Loss is:  0.09282126554526188  at  2116  iteration(s) at  ぺ .
# Loss is:  0.051250779812898155  at  2117  iteration(s) at  ぺ .
# Loss is:  0.004820564138875485  at  2118  iteration(s) at  あ .
# Loss is:  0.003113172412823375  at  2119  iteration(s) at  ね .
# Loss is:  0.06562656832626748  at  2120  iteration(s) at  は .
# Loss is:  0.13671530180158778  at  2121  iteration(s) at  ぞ .
# Loss is:  0.13068092797061456  at  2122  iteration(s) at  ず .
# Loss is:  0.011192308005120452  at  2123  iteration(s) at  わ .
# Loss is:  0.012410167420676346  at  2124  iteration(s) at  お .
# Loss is:  0.07867255294593091  at  2125  iteration(s) at  で .
# Loss is:  0.032333415524403566  at  2126  iteration(s) at  ふ .
# Loss is:  0.013762882286726731  at  2127  iteration(s) at  し .
# Loss is:  0.15023012643409778  at  2128  iteration(s) at  で .
# Loss is:  0.0004490597208038349  at  2129  iteration(s) at  ず .
# Loss at epoch =  0.06775137011882253
# Epoch  20  completed.
# Finished!

# %%
#session for predictions
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

################################################################################
######################### Convolution Neural Net Class #########################
#regarding weightMatrix, layerMatrix, derivativeMatrix
#defined as ""matrix[layer][(row,)-matrix] for layerMatrix/derivativeMatrix, where row = # of nodes 
#defined as ""matrix[layer][(row,col)-matrix] for weightMatrix/derivativeMatrix, where row = size of flattened sample, col = # of nodes


class cnn(object):
  def __init__(self, learning_rate=0.0005):
    self.c = learning_rate
    self.weightMatrix = [np.empty(shape=(0,0)),np.empty(shape=(0,0))]  #list holding weights from each time weight was called.
    self.layerMatrix = [np.empty(shape=(0,0)),np.empty(shape=(0,0)),np.empty(shape=(0,0))] #list holding node values from each dense layer 
    self.derivativeMatrix = [np.empty(shape=(0,0)),np.empty(shape=(0,0))] #list holding derivatives for each layer
    self.char = ['あ','い','う','え','お','か','が','き','ぎ','く','ぐ','け','げ','こ','ご','さ','ざ','し','じ','す','ず','せ','ぜ','そ','ぞ','た','だ','ち','ぢ','つ','づ','て','で','と','ど','な','に','ぬ','ね','の','は','ば','ぱ','ひ','び','ぴ','ふ','ぶ','ぷ','へ','べ','ぺ','ほ','ぼ','ぽ','ま','み','む','め','も','や','ゆ','よ','ら','り','る','れ','ろ','わ','を','ん',]
    self.correct = 0
    self.accuracyF = np.empty(shape=(0,), dtype=float)
    self.lossF = np.empty(shape=(0,), dtype=float)

  def conv1(self, input, kernel_size=(3,3), strides=(1,1), padding = 2):
    input = input
    kernel1 = np.array([[[0,-3,0],[-3,15,-3],[0,-3,0]]]) #sharpening filter
    kernel2 = np.array([[[-5,-15,-5],[0,0,0],[5,15,5]]]) #vertical filter
    kernel3 = np.array([[[-5,0,5],[-15,0,15],[-5,0,5]]]) #horizontal filter    
    filter = np.concatenate((kernel1, kernel2, kernel3))
    output = np.zeros(shape=(filter.shape[0], input.shape[0]-2, input.shape[1]-2))
    window = np.zeros(shape=(3,3))
    B = -1
    for i in range(filter.shape[0]): #per kernel
      for j in range(input.shape[0] - 2 ):  #rows
        for k in range(input.shape[1] - 2 ): #columns 
          window = input[j:j+3, k:k+3]   #select window 
          activation = self.ReLu( np.sum(np.tensordot(window, filter[i])) + B) #
          output[i,j,k] = activation #Y = B + X*K and activation 
    return output
  
  def conv2(self, input, kernel_size=(3,3), strides=(1,1), padding=2):
    input = input
    kernel1 = np.array([[[0,-1,0],[-1,5,-1],[0,-1,0]]]) #vertical filter
    kernel2 = np.array([[[-1,-2,-1],[0,0,0],[1,2,1]]]) #vertical filter
    kernel3 = np.array([[[-1,0,1],[-2,0,2],[-1,0,1]]]) #horizontal filter
    filter = np.concatenate((kernel1, kernel2, kernel3))
    output = np.zeros(shape=(input.shape[0], input.shape[1]-2, input.shape[2]-2))
    window = np.zeros(shape=(3,3))
    B = -1
    for i in range(input.shape[0]):
      for j in range(input.shape[1] - 2 ):  #rows
        for k in range(input.shape[2] - 2 ): #columns 
          window = input[i, j:j+3, k:k+3]   #select window 
          activation = self.ReLu( np.sum(np.tensordot(window, filter[i])) + B) 
          output[i,j,k] = activation #Y = B + X*K and activation
    return output

  def conv3(self, input, kernel_size=(3,3), strides=(1,1), padding=2):
    input = input
    kernel1 = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]]) #sharpening filter
    output = np.zeros(shape=(input.shape[0], input.shape[1]-2, input.shape[2]-2))
    window = np.zeros(shape=(3,3))
    B = -1
    for i in range(input.shape[0]): #per kernel
      for j in range(input.shape[1] - 2 ):  #rows
        for k in range(input.shape[2] - 2 ): #columns 
          window = input[i, j:j+3, k:k+3]   #select window 
          activation = self.ReLu( np.sum(np.tensordot(window, kernel1)) + B) #
          output[i,j,k] = activation #Y = B + X*K and activation
    return output

  def pooling(self, input, pool_size=(2,2), strides=(2,2)):
    self.arr = input  #input set of convoluted images 
    output = np.zeros(shape=(input.shape[0], int(input.shape[1]/strides[0]), int(input.shape[2]/strides[1]))) #shape of output
    for i in range(self.arr.shape[0]): #per feature map
      for j in range(0, self.arr.shape[1], strides[0]): #rows
        for k in range(0, self.arr.shape[2], strides[1]): #columns
          if int(j/2) >= output.shape[1] or int(k/2) >= output.shape[2]: break
          window = self.arr[i, j:j+strides[0], k:k+strides[1]]   #select window    #mistake: you set self.arr to np.arr instead, generating random vals
          output[i,int(j/2),int(k/2)] = np.max(window)   #get max from window
    return output   #output pool layers

  def flatten(self, input):
    output = np.reshape(input, input.size)    #reshape all array elements into a 1d array
    return output #output flattened layers

  def denseSetup(self, input, layers, nodes, skip=False):
    random = np.random.RandomState(1)
    self.layerMatrix[0] = np.zeros(shape=(input.size+1,))
    self.layerMatrix[1] = np.zeros(shape=(nodes[0],))
    self.layerMatrix[2] = np.zeros(shape=(nodes[1],))
    for i in range(layers):
      if skip == False:
        self.weightMatrix[i] = random.normal(loc=0.0, scale=0.1, size=(self.layerMatrix[i].shape[0], nodes[i])) #weights per node
      self.derivativeMatrix[i] = np.zeros(shape=(nodes[i],)) #layer derivatives 
  
  def denseNetwork(self, input): #forward, backward, on all samples of given epoch
    self.layerMatrix[0] = input  #input layer
    self.layerMatrix[0] = np.append(self.layerMatrix[0], 1)
    self.layerMatrix[0] = self.layerMatrix[0] / 10
    l=0
    for l in range(len(self.layerMatrix)-1):
      next = l + 1
      for i in range(self.layerMatrix[next].shape[0]):  #next layer num nodes
        if next == len(self.layerMatrix)-1: 
          self.layerMatrix[next][i] = np.dot(self.layerMatrix[l], self.weightMatrix[l][:,i])
        else: 
          self.layerMatrix[next][i] = self.ReLu(np.dot(self.layerMatrix[l], self.weightMatrix[l][:,i]))
    self.layerMatrix[2] = self.softMax(self.layerMatrix[len(self.layerMatrix)-1]) #output layer
    self.layerMatrix[2][np.abs(self.layerMatrix[2]) < 1e-7] = 1e-7 #array[np.abs(array) < eps] = 0
    self.biggest = np.argmax(self.layerMatrix[2])
    return self.layerMatrix[2]

  def denseBack(self, loss):
    derivative1 = np.zeros(shape=(self.layerMatrix[2].shape[0]))  #derivative array at output
    derivative2 = np.zeros(shape=(self.layerMatrix[1].shape[0]))  #derivative array at hidden

    #output layer to hidden layer 
    for i in range(self.layerMatrix[1].shape[0]):  #for layer below current (hidden)
      for j in range(self.layerMatrix[2].shape[0]):  #for current layer (output)
        derivative1[j] = -self.target[j] + self.layerMatrix[2][j]   #crossentropy loss - softmax derivative
        dLayer = self.layerMatrix[1][i]*derivative1[j]*self.c #- self.m*derivative1[j]  #activation*derivative*learning rate
        self.weightMatrix[1][i,j] -= dLayer

    #hidden layer to flatten layer 
    for i in range(self.layerMatrix[0].shape[0]):
      for j in range(self.layerMatrix[1].shape[0]):
        derivative2[j] = np.greater(self.layerMatrix[1][j], 0).astype(int)*np.dot(derivative1, self.weightMatrix[1][j])  #relu - past derivative derivative
        dLayer = self.layerMatrix[0][i]*derivative2[j]*self.c #- self.m*derivative2[j]
        self.weightMatrix[0][i,j] -= dLayer

  def ReLu(self, input):
    return max(0.0, input)   #hinge activation function, return value if greater than 0.0, otherwise return 0.0

  def Loss(self, output):    #categorical cross-entropy loss
    return -np.sum(self.target*np.log(output))   #loss = -sum(class*ln(output))

  def softMax(self, input):
    return np.exp(input)/np.sum(np.exp(input), axis=0)

  def encode(self, classes, target):
    target.fill(0) 
    target[classes] = 1
    return target

  def predictPreloaded(self, data, targets):
    self.loadWeights()
    self.target = np.zeros((71,),dtype=int)
    for i in range(data.shape[0]):
      input = data[i]
      input = self.conv1(input=input)
      input = self.pooling(input=input)
      input = self.conv2(input=input)
      input = self.pooling(input=input)
      input = self.conv3(input=input)
      input = self.flatten(input=input)
      if i == 0: 
        self.denseSetup(input, layers=2,nodes=[384,71], skip=True)
      output = self.denseNetwork(input=input)
      self.target = self.encode(targets[i], self.target)
      if np.argmax(output) == targets[i]:
        self.correct += 1
      print("predicted: ", self.char[np.argmax(output)], ", actual: ", self.char[targets[i]])
    print("Predicition Accuracy Rate: ", 100*(self.correct/data.shape[0]))   #(self.accuracy.shape[0]/data.shape[0]), "%")
    self.correct = 0

  def predict(self, data, targets):
    for i in range(data.shape[0]):
      input = data[i]
      input = self.conv1(input=input)
      input = self.pooling(input=input)
      input = self.conv2(input=input)
      input = self.pooling(input=input)
      input = self.flatten(input=input)
      output = self.denseNetwork(input=input)
      if np.argmax(output) == targets[i]:
        self.correct += 1
      print("predicted: ", np.argmax(output))
      print("actual: ", targets[i])
    print("Prediction Accuracy Rate: ", 100*(self.accuracy.shape[0]/data.shape[0]), "%")
    self.accuracyF = np.append(self.accuracyF, 100*(self.correct/data.shape[0]))  #(self.accuracy.shape[0]/data.shape[0]))
    self.correct = 0 

  
  def fit(self, features, classes, epochs): #, valid_data):
    rest, features, restid, classes = train_test_split(images, classes, test_size=0.1875,  stratify=classes)
    """main training function"""
    self.target = np.zeros((71,),dtype=int)
    self.lossE = np.zeros(shape=(0,))
    error = 100
    epochLoss = 0
    print("Starting training...")
    for e in range(epochs):
      for i in range(features.shape[0]):
        if i > 50 and np.sum(self.lossF[i-50:i])/50 <= 1e-2:
          print("Early breaking condition reached. Acceptable loss range hit.")
          print("Loss was: ", error)
          self.saveWeights()
          return self
        ##################################
        ########## forward pass ##########
        input = features[i]
        input = self.conv1(input=input)
        input = self.pooling(input=input)
        input = self.conv2(input=input)
        input = self.pooling(input=input)
        input = self.conv3(input=input)
        input = self.flatten(input=input)
        if e == 0 and i == 0: 
          self.denseSetup(input, layers=2,nodes=[384,71])
        self.target = self.encode(classes[i], self.target)
        output = self.denseNetwork(input=input)
        ##########################
        ########## loss ##########
        error = self.Loss(output)
        self.lossF = np.append(self.lossF, error) #[i] = error
        epochLoss += error
        ###############################
        ########## back pass ##########
        self.denseBack(error)
        # if i % 100 == 0 and i > 0:    #every 100 iterations, test validation data
        #   self.predict(valid_data[0][int(i/10)-10:i], valid_data[1][int(i/10)-10:i])  #features, classes) #valid_data[0], valid_data[1])
        #   print("Loss is: ", error, " at ", i, " iterations.")
        print("Loss is: ", error, " at ", i, " iteration(s) at ", self.char[classes[i]], ".")
      self.lossE = np.append(self.lossE, epochLoss/features.shape[0]) #self.lossF.size)
      epochLoss = 0
      print("Loss at epoch = ", self.lossE[e])
      print("Epoch ", e+1, " completed.")
    print("Finished!")
    self.saveWeights()
    return self
  def saveWeights(self):
    w = np.asarray(self.weightMatrix, dtype=object)
    with open('weightsHiragana.npy', 'wb') as f:
      np.save(f, w)
  
  def loadWeights(self):
    with open('weightsHiragana.npy', 'rb') as f:
      temp = np.load(f, allow_pickle=True)
    for i in range(len(self.weightMatrix)):
      self.weightMatrix[i] = temp[i]
    assert len(self.weightMatrix) == 2

############################################################################
############################## Data Init ##############################

loaded = np.load('hiraganaR.npz')
images = loaded['a']
classes = loaded['b']
rest, features, restid, classes = train_test_split(images, classes, test_size=0.0126,  stratify=classes)

########################################################################
############################## Model Init ##############################

model = cnn().predictPreloaded(features, classes)
# Out:
# (11360, 48, 48) (11360,)
# 2
# predicted:  ち , actual:  ち
# predicted:  ぴ , actual:  ぴ
# predicted:  ぼ , actual:  ぽ
# predicted:  ぽ , actual:  ぽ
# predicted:  し , actual:  し
# predicted:  ぶ , actual:  ぷ
# predicted:  ぐ , actual:  ぐ
# predicted:  ぽ , actual:  ぼ
# predicted:  こ , actual:  と
# predicted:  そ , actual:  そ
# predicted:  せ , actual:  せ
# predicted:  ぢ , actual:  ぢ
# predicted:  が , actual:  が
# predicted:  ぶ , actual:  ぶ
# predicted:  で , actual:  で
# predicted:  を , actual:  き
# predicted:  か , actual:  か
# predicted:  ぱ , actual:  ぱ
# predicted:  け , actual:  せ
# predicted:  げ , actual:  げ
# predicted:  に , actual:  に
# predicted:  ぱ , actual:  ば
# predicted:  の , actual:  の
# predicted:  ろ , actual:  ろ
# predicted:  す , actual:  ず
# predicted:  れ , actual:  れ
# predicted:  ゆ , actual:  ゆ
# predicted:  ほ , actual:  ぺ
# predicted:  ぬ , actual:  ぬ
# predicted:  さ , actual:  さ
# predicted:  て , actual:  で
# predicted:  お , actual:  お
# predicted:  す , actual:  す
# predicted:  む , actual:  む
# predicted:  こ , actual:  ご
# predicted:  ぷ , actual:  ぴ
# predicted:  ぢ , actual:  ぢ
# predicted:  ぺ , actual:  べ
# predicted:  ぴ , actual:  び
# predicted:  ざ , actual:  ざ
# predicted:  ぼ , actual:  ぼ
# predicted:  ん , actual:  ぬ
# predicted:  ね , actual:  ね
# predicted:  か , actual:  か
# predicted:  へ , actual:  へ
# predicted:  お , actual:  お
# predicted:  び , actual:  ひ
# predicted:  す , actual:  す
# predicted:  ぞ , actual:  ぞ
# predicted:  け , actual:  け
# predicted:  ぎ , actual:  ぎ
# predicted:  み , actual:  み
# predicted:  や , actual:  や
# predicted:  こ , actual:  だ
# predicted:  な , actual:  な
# predicted:  し , actual:  し
# predicted:  み , actual:  み
# predicted:  を , actual:  を
# predicted:  む , actual:  む
# predicted:  る , actual:  る
# predicted:  で , actual:  ぞ
# predicted:  つ , actual:  つ
# predicted:  け , actual:  け
# predicted:  ろ , actual:  へ
# predicted:  ぜ , actual:  ぜ
# predicted:  ち , actual:  ら
# predicted:  じ , actual:  じ
# predicted:  ろ , actual:  ん
# predicted:  ぬ , actual:  め
# predicted:  び , actual:  び
# predicted:  お , actual:  ぶ
# predicted:  こ , actual:  こ
# predicted:  て , actual:  て
# predicted:  ば , actual:  だ
# predicted:  ず , actual:  や
# predicted:  る , actual:  る
# predicted:  づ , actual:  づ
# predicted:  る , actual:  ろ
# predicted:  ぺ , actual:  ぺ
# predicted:  よ , actual:  よ
# predicted:  そ , actual:  そ
# predicted:  い , actual:  い
# predicted:  へ , actual:  べ
# predicted:  く , actual:  な
# predicted:  と , actual:  と
# predicted:  ど , actual:  ど
# predicted:  ぶ , actual:  ふ
# predicted:  は , actual:  げ
# predicted:  こ , actual:  く
# predicted:  ば , actual:  ば
# predicted:  が , actual:  が
# predicted:  ま , actual:  ま
# predicted:  さ , actual:  え
# predicted:  ざ , actual:  ざ
# predicted:  ら , actual:  ら
# predicted:  ね , actual:  た
# predicted:  う , actual:  う
# predicted:  ほ , actual:  は
# predicted:  に , actual:  に
# predicted:  あ , actual:  あ
# predicted:  ふ , actual:  ふ
# predicted:  と , actual:  ど
# predicted:  も , actual:  え
# predicted:  ひ , actual:  ひ
# predicted:  は , actual:  は
# predicted:  ほ , actual:  ほ
# predicted:  で , actual:  で
# predicted:  つ , actual:  つ
# predicted:  ぱ , actual:  ぱ
# predicted:  た , actual:  た
# predicted:  へ , actual:  さ
# predicted:  も , actual:  も
# predicted:  う , actual:  う
# predicted:  こ , actual:  こ
# predicted:  ゆ , actual:  ゆ
# predicted:  い , actual:  い
# predicted:  り , actual:  り
# predicted:  ね , actual:  あ
# predicted:  も , actual:  も
# predicted:  ぎ , actual:  き
# predicted:  ご , actual:  ご
# predicted:  ゆ , actual:  り
# predicted:  ぐ , actual:  く
# predicted:  を , actual:  を
# predicted:  わ , actual:  わ
# predicted:  じ , actual:  じ
# predicted:  ず , actual:  ず
# predicted:  ね , actual:  ね
# predicted:  ひ , actual:  の
# predicted:  ぐ , actual:  ぐ
# predicted:  ち , actual:  ち
# predicted:  ん , actual:  ん
# predicted:  わ , actual:  わ
# predicted:  ず , actual:  ず
# predicted:  よ , actual:  よ
# predicted:  つ , actual:  づ
# predicted:  ざ , actual:  ぎ
# predicted:  は , actual:  ほ
# predicted:  ぜ , actual:  ぜ
# predicted:  ぬ , actual:  め
# predicted:  ま , actual:  ま
# predicted:  わ , actual:  れ
# predicted:  ぷ , actual:  ぷ
# predicted:  せ , actual:  て
# Predicition Accuracy Rate:  66.66666666666666
